# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from simpledbf import Dbf5
import pyxlsb
import os
import time
import random
from shapely.geometry import MultiLineString, LineString, Point
import math
import shapely

import create_gtfs_from_basicinfo
import sys, os
import zipfile
import shutil
# Out:
# /Users/frankiemacbook/opt/miniconda3/envs/py3/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(
# PyTables is not installed. No support for HDF output.
# SQLalchemy is not installed. No support for SQL output.

# %%
start_time = time.time()

rootdir = '/Users/frankiemacbook/OneDrive - VicGov/VITM/GTFS/Ref case'

fullpaths = map(lambda name: os.path.join(rootdir, name), os.listdir(rootdir))
dirs = [x for x in fullpaths if os.path.isdir(x)]
years = sorted([x.rsplit('/', 1)[-1] for x in dirs])
years
# Out:
# ['2018', '2026', '2031', '2036', '2041', '2051']

# %%
data = pd.DataFrame()
for year in years:
    dbf = Dbf5(rootdir+'/'+year+'/PTLINK_ALL_Y'+year+'_VR19_Ref_C.DBF')
    temp = dbf.to_dataframe()
    temp.insert(0,'year',year)
    data = data.append(temp, ignore_index=True)
data = data[['PERIOD','A','B','VEHNAME','LINENO','LINKSEQ','STOPA','STOPB','NAME','LONGNAME','year']]
data['YEAR_LINE_PERIOD'] = data['year'] + "_" + data['LINENO'].apply(str) + "_" + data['PERIOD']
data['YEAR_LINE'] = data['year'] + "_" + data['LINENO'].apply(str)
data['A_B'] = data['A'].apply(str) + "_" + data['B'].apply(str)

# %%
tram_names = data.loc[data['VEHNAME'].str.contains("^(?:Tram)")]['VEHNAME'].unique().tolist()
vline_names = data.loc[data['VEHNAME'].str.contains("^(?:V[Ll]ine)")]['VEHNAME'].unique().tolist() + ['SP2']
train_names = data.loc[(data['VEHNAME'].str.contains("^(?:Metro)")) | \
                       (data['VEHNAME'].str.contains("^(?:HCMT)")) | \
                       (data['VEHNAME'].str.contains("^(?:COMENG)")) | \
                       (data['VEHNAME'].str.contains("^(?:SRL)"))]['VEHNAME'].unique().tolist()

replace_dict = {'Bus':'bus','SkyBus':'skybus'}
for name in tram_names:
    replace_dict[name] = 'tram'
for name in vline_names:
    replace_dict[name] = 'vline'
for name in train_names:
    replace_dict[name] = 'train'

data['VEHNAME'] = data['VEHNAME'].replace(replace_dict)
data = data.rename(columns = {'VEHNAME':'mode'})
all_modes = sorted(data['mode'].unique().tolist())
all_modes
# Out:
# ['bus', 'skybus', 'train', 'tram', 'vline']

# %%
ignore_fields_list = ['REGION','LINKC_IP','LINKC_PM','LINKC_OP', 'LANES_AM', 'LANES_IP', 'LANES_PM', 'LANES_OP', 'PSPD_AM', 'PSPD_IP', 'PSPD_PM', 'PSPD_OP', 'TOLLROAD', \
                      'TOLLGANT', 'TOLLENTRY', 'TOLLEXIT', 'TURN_BAN', 'CLEARWAY', 'ROADTYPE', 'RD_NAME', 'LASTPROJ', 'LX', 'LX_CODE', 'CROSSING', 'LXCLOSE', 'CTIME', \
                      'RAIL_SPD', 'TRAM_SPD3', 'BFLG_AM', 'BFLG_PM', 'SL', 'SL_CODE', 'TTR', 'TRN_CRDN', 'VLN_CRDN', 'TRM_CRDN', 'CRDN_DIR', 'FFSPD_AM', \
                      'FFSPD_IP', 'FFSPD_PM', 'FFSPD_OP', 'FFTIME_AM', 'FFTIME_IP', 'FFTIME_PM', 'FFTIME_OP', 'CSPD_AM', 'CSPD_IP', 'CSPD_PM', 'CSPD_OP', 'TIME_AM', \
                      'TIME_IP', 'TIME_PM', 'TIME_OP', 'TRSTIME_AM', 'TRSTIME_IP', 'TRSTIME_PM', 'TRSTIME_OP', 'TRMTIME_AM', 'TRMTIME_IP', 'TRMTIME_PM', 'TRMTIME_OP', \
                      'BUSTIME_AM', 'BUSTIME_IP', 'BUSTIME_PM', 'BUSTIME_OP', 'SMBTIME_AM', 'SMBTIME_IP', 'SMBTIME_PM', 'SMBTIME_OP', 'SKBTIME_AM', 'SKBTIME_IP', \
                      'SKBTIME_PM', 'SKBTIME_OP', 'SPBTIME_AM', 'SPBTIME_IP', 'SPBTIME_PM', 'SPBTIME_OP', 'VEH_AM', 'VEH_IP', 'VEH_PM', 'VEH_OP', 'VEH_WD', 'PVV_AM', \
                      'PVV_IP', 'PVV_PM', 'PVV_OP', 'PVV_WD', 'AP_EMP_AM', 'AP_EMP_IP', 'AP_EMP_PM', 'AP_EMP_OP', 'AP_EMP_WD', 'AP_PAS_AM', 'AP_PAS_IP', 'AP_PAS_PM', \
                      'AP_PAS_OP', 'AP_PAS_WD', 'TRUCK_AM', 'TRUCK_IP', 'TRUCK_PM', 'TRUCK_OP', 'TRUCK_WD', 'RIGID_AM', 'RIGID_IP', 'RIGID_PM', 'RIGID_OP', 'RIGID_WD', \
                      'ARTIC_AM', 'ARTIC_IP', 'ARTIC_PM', 'ARTIC_OP', 'ARTIC_WD', 'BDBLE_AM', 'BDBLE_IP', 'BDBLE_PM', 'BDBLE_OP', 'BDBLE_WD', 'HPFV_AM', 'HPFV_IP', \
                      'HPFV_PM', 'HPFV_OP', 'HPFV_WD', 'PCU_AM', 'PCU_IP', 'PCU_PM', 'PCU_OP', 'PCU_WD', 'VEH_VKT_AM', 'VEH_VKT_IP', 'VEH_VKT_PM', 'VEH_VKT_OP', \
                      'PVV_VKT_AM', 'PVV_VKT_IP', 'PVV_VKT_PM', 'PVV_VKT_OP', 'HCV_VKT_AM', 'HCV_VKT_IP', 'HCV_VKT_PM', 'HCV_VKT_OP', 'VEH_VHT_AM', 'VEH_VHT_IP', \
                      'VEH_VHT_PM', 'VEH_VHT_OP', 'PVV_VHT_AM', 'PVV_VHT_IP', 'PVV_VHT_PM', 'PVV_VHT_OP', 'HCV_VHT_AM', 'HCV_VHT_IP', 'HCV_VHT_PM', 'HCV_VHT_OP', \
                      'HYCAP_AM', 'HYCAP_IP', 'HYCAP_PM', 'HYCAP_OP', 'VC_AM', 'VC_IP', 'VC_PM', 'VC_OP', 'PT_AM', 'PT_IP', 'PT_PM', 'PT_OP', 'PT_WD', 'TRAIN_AM', \
                      'TRAIN_IP', 'TRAIN_PM', 'TRAIN_OP', 'TRAIN_WD', 'TRAM_AM', 'TRAM_IP', 'TRAM_PM', 'TRAM_OP', 'TRAM_WD', 'BUS_AM', 'BUS_IP', 'BUS_PM', 'BUS_OP', \
                      'BUS_WD', 'VLINE_AM', 'VLINE_IP', 'VLINE_PM', 'VLINE_OP', 'VLINE_WD', 'WLK_AE_AM', 'WLK_AE_IP', 'WLK_AE_PM', 'WLK_AE_OP', 'WLK_AE_WD', \
                      'PNR_AE_AM', 'PNR_AE_IP', 'PNR_AE_PM', 'PNR_AE_OP', 'PNR_AE_WD', 'PNR_VH_AM', 'PNR_VH_IP', 'PNR_VH_PM', 'PNR_VH_OP', 'PNR_VH_WD', 'TFTMBU_AM', \
                      'TFTMBU_IP', 'TFTMBU_PM', 'TFTMBU_OP', 'TFTMBU_WD', 'TFRLRL_AM', 'TFRLRL_IP', 'TFRLRL_PM', 'TFRLRL_OP', 'TFRLRL_WD', 'TRNNVEH_AM', 'TRNNVEH_IP', \
                      'TRNNVEH_PM', 'TRNNVEH_OP', 'TRMNVEH_AM', 'TRMNVEH_IP', 'TRMNVEH_PM', 'TRMNVEH_OP', 'BUSNVEH_AM', 'BUSNVEH_IP', 'BUSNVEH_PM', 'BUSNVEH_OP', \
                      'VLNNVEH_AM', 'VLNNVEH_IP', 'VLNNVEH_PM', 'VLNNVEH_OP', 'TRNCAP_AM', 'TRNCAP_IP', 'TRNCAP_PM', 'TRNCAP_OP', 'TRN_VC_AM', 'TRN_VC_IP', \
                      'TRN_VC_PM', 'TRN_VC_OP', 'TRMCAP_AM', 'TRMCAP_IP', 'TRMCAP_PM', 'TRMCAP_OP', 'TRM_VC_AM', 'TRM_VC_IP', 'TRM_VC_PM', 'TRM_VC_OP', 'BUSCAP_AM', \
                      'BUSCAP_IP', 'BUSCAP_PM', 'BUSCAP_OP', 'BUS_VC_AM', 'BUS_VC_IP', 'BUS_VC_PM', 'BUS_VC_OP', 'VLNCAP_AM', 'VLNCAP_IP', 'VLNCAP_PM', 'VLNCAP_OP', \
                      'VLN_VC_AM', 'VLN_VC_IP', 'VLN_VC_PM', 'VLN_VC_OP', 'PTCAP_AM', 'PTCAP_IP', 'PTCAP_PM', 'PTCAP_OP', 'PT_VC_AM', 'PT_VC_IP', 'PT_VC_PM', 'PT_VC_OP']

network = pd.DataFrame()
for year in years[:1]:
    temp = gpd.read_file(rootdir+'/'+year+'/SUMMARY_LOADED_NETWORK_LINKS_Y'+year+'_VR19_Ref_C.shp',ignore_fields=ignore_fields_list)
    temp = temp.loc[~temp['LINKC_AM'].isin([1,-1])]
    temp['A_B'] = temp['A'].apply(str) + "_" + temp['B'].apply(str)
    temp = temp.set_index('A_B')
    missing_index = temp.index.difference(network.index)
    network = network.append(temp.loc[missing_index, :])
network = network.reset_index().rename(columns = {'index':'A_B'})
network = gpd.GeoDataFrame(network, geometry='geometry')
network.crs=('epsg:20255')
network['DISTANCE'] = network['geometry'].length

# %%
pt_reporting = pd.DataFrame()
for year in years:
    temp = pd.read_excel(rootdir+'/'+year+'/DetailedPTReporting_v200619_Y'+year+'_VR19_Ref_C.xlsb', sheet_name='Line Summary', engine='pyxlsb', skiprows=2)
    temp.insert(0,'year',year)
    pt_reporting = pt_reporting.append(temp, ignore_index=True)

# %%
temp_data = data.merge(network[['DISTANCE','A_B','geometry']], how='left', on='A_B').reset_index()

# %%
segs = temp_data.groupby('A_B').first()[['index','mode','A','B','STOPA','STOPB','DISTANCE','geometry']]

# %%
missing_links = segs.loc[segs['DISTANCE'].isnull()]

# %%
def find_shortest_path(row):
    
    if row['node_path'] is None:
        
        global rows_processed, segs_not_found
        start_time = time.time()
        too_long = False
        bounding_nodes = [temp_data.loc[row['index']-1,'A'],temp_data.loc[row['index']+1,'B']]
        mode = row['mode']
        start_node = row['A']
        end_node = row['B']
        depth = 1
        max_depth = 500
        max_time = 90
        node_tree = [[start_node]]
        rows_processed +=1
        print('Finding missing nodes: %.1f' % (100 * rows_processed / total_rows) + '% pairs processed                      ', end='\r')
        if row['next_nodes'] is not None:
            node_tree = [node_tree[0] + row['next_nodes']]
            max_depth = 500
            max_time = 120
        while True:
            if (time.time() - start_time > 30) and too_long == False:
                print('Node pair ('+str(start_node)+', '+str(end_node)+') is taking a long time to process', end='\r')
                too_long = True
            new_tree = []
            for nodes in node_tree:
                try:
                    if mode in ['train','vline']:
                        new_nodes = network.loc[(network['A'] == nodes[-1]) & (network['LINKC_AM'] == 42), 'B'].to_list()
                    else:
                        new_nodes = network.loc[(network['A'] == nodes[-1]) & (network['LINKC_AM'] != 42), 'B'].to_list()
                    if any(x == end_node for x in new_nodes):
                        nodes.append(end_node)
                        row['node_path'] = split_list(nodes)
                        return row
                    if (depth >= 5) and (len(new_nodes) > 2) and (random.random() < 0.5):
                        new_nodes = []
                    for new_node in new_nodes:
                        if new_node not in nodes + bounding_nodes:
                            nodes_copy = nodes.copy()
                            nodes_copy.append(new_node)
                            new_tree.append(nodes_copy)
                except:
                    None
            node_tree = new_tree
            depth += 1
            if (depth == max_depth) or (len(node_tree) > 50000) or (time.time() - start_time > max_time):
                segs_not_found.append('"A"='+str(start_node)+' OR "B"='+str(end_node))
#                 print('Node pair ('+str(start_node)+', '+str(end_node)+') not found at depth='+str(depth)+' and tree length='+str(len(node_tree)), end='\r')
                row['node_path'] = None
    return row

def split_list(l):
    new_list = []
    for i in range(len(l)-1):
        new_list.append((l[i],l[i+1]))
    return new_list

missing_links.insert(0,'node_path',None)
missing_links.insert(0,'next_nodes',None)

next_nodes = {'23237_23051':[23212,23191,23188],
              '14610_23262':[23377,23375,23376],
              '10322_19292':[30688,30682,30677],
              '220608_44422':[220609,220610,220612],
              '23051_23237':[23059,23060,23066],
              '23262_14610':[23257,23253,23252],
              '44422_220608':[220102,220103,220104],
              '19292_10322':[30935,30937,30909],
              '27950_26914':[27933,27928,27924],
              '18386_233825':[279141,279140,279139],
              '233825_18386':[279144,279145,279146],
              '223580_15575':[223581,224430,224431]}

for k in next_nodes:
    if k in missing_links.index:
        missing_links.at[k,'next_nodes'] = next_nodes[k]

total_rows = missing_links.shape[0]
rows_processed = 0

segs_not_found = []
missing_links = missing_links.apply(find_shortest_path, axis=1)
if len(segs_not_found) > 0:
    print("\nSegments not found:")
    for s in segs_not_found:
        print(s)
        
# import os
# os.system("printf '\a'")
# Out:
# Finding missing nodes: 100.0% pairs processed

# %%
def pad_stops(group):
    group['STOPB'].iloc[:-1] = 0
    group['STOPA'].iloc[1:] = 0
    return group

if missing_links.size != 0:
    
    ml_expand = missing_links[['index','A','B','STOPA','STOPB']] \
        .merge(missing_links.node_path.explode(), right_index = True, left_index = True) \
        .dropna() \
        .sort_values(['index','A','B']) \
        .reset_index(drop = True)

    ml_expand['A_B'] = ml_expand['A'].apply(str) + "_" + ml_expand['B'].apply(str)

    ml_expand = ml_expand.sort_values(['A_B','index'])
    ml_expand = ml_expand.groupby('A_B').apply(pad_stops)

    temp_data = temp_data.merge(ml_expand[['A_B','STOPA','STOPB','node_path']], how='left', on='A_B', suffixes=('','_y')).sort_values(['year','LINENO','PERIOD','LINKSEQ']).reset_index(drop=True)

    temp_data[['new_A','new_B']] = pd.DataFrame(temp_data.loc[temp_data['node_path'].notnull(), 'node_path'].tolist(), index=temp_data.loc[temp_data['node_path'].notnull()].index)

    temp_data['STOPA'] = np.where(temp_data['node_path'].notnull(), temp_data['STOPA_y'], temp_data['STOPA'])
    temp_data['STOPB'] = np.where(temp_data['node_path'].notnull(), temp_data['STOPB_y'], temp_data['STOPB'])
    temp_data['A'] = np.where(temp_data['node_path'].notnull(), temp_data['new_A'], temp_data['A'])
    temp_data['B'] = np.where(temp_data['node_path'].notnull(), temp_data['new_B'], temp_data['B'])

    temp_data = temp_data.drop(['node_path', 'new_A', 'new_B', 'STOPA_y', 'STOPB_y'], axis=1)

    temp_data['A'] = temp_data['A'].apply(int)
    temp_data['B'] = temp_data['B'].apply(int)

    temp_data['A_B'] = temp_data['A'].apply(str) + "_" + temp_data['B'].apply(str)

df = temp_data.drop(['index','DISTANCE','geometry'], axis=1).merge(network[['LINKC_AM','A_B','DISTANCE','BUS_SPD','geometry']], how='left', on='A_B').replace(np.nan,"NaN")

# %%
# short_links = network.loc[network['DISTANCE'] < 5]
# for index, row in short_links.iterrows():
#     next_nodes = network.loc[(network['A'] == row['B']) & (network['B'] != row['A']) & (network['LINKC_AM'] == row['LINKC_AM'])]
#     if next_nodes.shape[0] == 1:
#         next_nodes = next_nodes.iloc[0]
#         if network.loc[(network['B'] == row['B']) & (~network['A'].isin([row['A'],next_nodes['B']]))].shape[0] == 0:
#             network.loc[index,'B'] = next_nodes['B']
#             network.loc[index,'geometry'] = LineString(list(network.loc[index,'geometry'].coords) + list(next_nodes['geometry'].coords[1:]))
#             network.loc[index,'DISTANCE'] = network.loc[index,'DISTANCE'] + next_nodes['DISTANCE']
#             network.loc[index,'A_B'] = str(network.loc[index,'A']) + '_' + str(network.loc[index,'B'])
#     else:
#         prev_nodes = network.loc[(network['B'] == row['A']) & (network['A'] != row['B']) & (network['LINKC_AM'] == row['LINKC_AM'])]
#         if prev_nodes.shape[0] == 1:
#             prev_nodes = prev_nodes.iloc[0]
#             if network.loc[(network['A'] == row['A']) & (~network['B'].isin([row['B'],prev_nodes['A']]))].shape[0] == 0:
#                 network.loc[index,'A'] = prev_nodes['A']
#                 network.loc[index,'geometry'] = LineString(list(prev_nodes['geometry'].coords[1:]) + list(network.loc[index,'geometry'].coords))
#                 network.loc[index,'DISTANCE'] = network.loc[index,'DISTANCE'] + prev_nodes['DISTANCE']
#                 network.loc[index,'A_B'] = str(network.loc[index,'A']) + '_' + str(network.loc[index,'B'])

# %%
# for k in next_nodes:
#     if k in missing_links.index:
#         missing_links.at[k,'next_nodes'] = next_nodes[k]

# total_rows = missing_links.loc[missing_links['node_path'] == 'NaN'].shape[0]
# rows_processed = 0

# segs_not_found = []
# missing_links = missing_links.apply(find_shortest_path, axis=1)
# if len(segs_not_found) > 0:
#     print("\nSegments not found:")
#     for s in segs_not_found:
#         print(s)

# %%
# del network

# del temp_data

# del temp
# del missing_index
# del segs
# del missing_links
# del ml_expand

# %%
df['LINKSEQ'] = df.groupby('YEAR_LINE_PERIOD').cumcount()
df = df.merge(df.groupby('YEAR_LINE_PERIOD')['B'].apply(list).apply(lambda x: '_'.join([str(y) for y in x])).reset_index().rename(columns={'B':'ROUTE_LIST'}), how='left', on='YEAR_LINE_PERIOD')

unique_routes = df.groupby('ROUTE_LIST').first().reset_index().reset_index().rename(columns={'index':'UNIQUE_ROUTE'})[['ROUTE_LIST','UNIQUE_ROUTE','YEAR_LINE_PERIOD']]

df = df.merge(unique_routes.drop('YEAR_LINE_PERIOD',axis=1), how='left', on='ROUTE_LIST').drop('ROUTE_LIST',axis=1)
df['UNIQUE_ROUTE_SEQ'] = df['UNIQUE_ROUTE'].apply(str) + '_' + df['LINKSEQ'].apply(str)

def assert_route_termini(group):
    group['STOPA'].iloc[0] = 1
    group['STOPB'].iloc[-1] = 1
    return group

df_unique = df.loc[df['YEAR_LINE_PERIOD'].isin(unique_routes['YEAR_LINE_PERIOD'].to_list())].sort_values(['UNIQUE_ROUTE','LINKSEQ']).groupby('UNIQUE_ROUTE').apply(assert_route_termini).sort_values(['UNIQUE_ROUTE','LINKSEQ']).reset_index(drop=True)
df_unique = df_unique[['A_B','A','B','STOPA','STOPB','LINKC_AM','BUS_SPD','DISTANCE','UNIQUE_ROUTE','UNIQUE_ROUTE_SEQ','LINKSEQ','mode','geometry']]

unique_AB_to_split = df_unique.groupby('A_B').first().reset_index()

unique_AB_to_split = unique_AB_to_split.loc[(unique_AB_to_split['mode'].isin(['bus','tram'])) & (~unique_AB_to_split['LINKC_AM'].isin([18,20,25])) & (unique_AB_to_split['BUS_SPD'] != 80)][['A_B','A','B','LINKC_AM','DISTANCE','geometry']]

# %%
unique_AB_to_split = gpd.GeoDataFrame(unique_AB_to_split,geometry='geometry')

# %%
unique_nodes = unique_AB_to_split.drop_duplicates(subset=['A'])[['A','geometry']].rename(columns={'A':'node'})
unique_nodes.geometry = unique_nodes.geometry.apply(lambda line: Point(line.coords[0]))
temp_B_nodes = unique_AB_to_split.drop_duplicates(subset=['B'])[['B','geometry']].rename(columns={'B':'node'})
temp_B_nodes.geometry = temp_B_nodes.geometry.apply(lambda line: Point(line.coords[-1]))
unique_nodes = unique_nodes.append(temp_B_nodes.loc[~temp_B_nodes['node'].isin(unique_nodes['node'].to_list())])
unique_nodes = gpd.GeoDataFrame(unique_nodes, geometry='geometry')

print(unique_nodes.shape[0])
# Out:
# 25815

# %%
total_rows = unique_AB_to_split.shape[0]
rows_processed = 0

def split_line(line, distance, segments):
    global unique_nodes, geoms
    line_segs = [line]
    for i in range(segments - 1):
        line = line_segs[-1]
        line_segs = line_segs[:-1]
        coords = list(line.coords)
        for i, p in enumerate(coords):
            dist = line.project(Point(p))
            if dist == distance:
                dist_to_nearest = unique_nodes.distance(Point(coords[i])).nsmallest(1)
                if dist_to_nearest.iloc[0] == 0:
                    line_segs += [LineString(coords[:i+1]), LineString(coords[i:])]
#                     print('existing node: '+','.join(str(c) for c in coords[i]))
                else:
                    if dist_to_nearest.iloc[0] < 5:
                        nearest_point = unique_nodes.loc[dist_to_nearest.index,'geometry'].iloc[0]
                        line_segs += [LineString(coords[:i] + [(nearest_point.x,nearest_point.y)]), LineString([(nearest_point.x,nearest_point.y)] + coords[i+1:])]
#                         print('nearby node: '+','.join(str(c) for c in coords[i])+' -> '+','.join(str(c) for c in [nearest_point.x,nearest_point.y]))
                    else:
                        line_segs += [LineString(coords[:i+1]), LineString(coords[i:])]
                        unique_nodes = unique_nodes.append(gpd.GeoDataFrame(pd.DataFrame([[np.nan,Point(coords[i])]],columns=['node','geometry']),geometry='geometry'),ignore_index=True)
#                         print('new node: '+','.join(str(c) for c in coords[i]))
                break
            if dist > distance:
                cp = line.interpolate(distance)
                dist_to_nearest = unique_nodes.distance(cp).nsmallest(1)
                if dist_to_nearest.iloc[0] == 0:
                    line_segs += [
                        LineString(coords[:i] + [(cp.x, cp.y)]),
                        LineString([(cp.x, cp.y)] + coords[i:])]
#                     print('existing node: '+','.join(str(c) for c in [cp.x, cp.y]))
                else:
                    dist_to_nearest = unique_nodes.distance(cp).nsmallest(1)
                    if dist_to_nearest.iloc[0] < 5:
                        nearest_point = unique_nodes.loc[dist_to_nearest.index,'geometry'].iloc[0]
                        line_segs += [LineString(coords[:i] + [(nearest_point.x,nearest_point.y)]), LineString([(nearest_point.x,nearest_point.y)] + coords[i:])]
#                         print('nearby node: '+','.join(str(c) for c in [cp.x, cp.y])+' -> '+','.join(str(c) for c in [nearest_point.x,nearest_point.y]))
                    else:
                        line_segs += [
                            LineString(coords[:i] + [(cp.x, cp.y)]),
                            LineString([(cp.x, cp.y)] + coords[i:])]
                        unique_nodes = unique_nodes.append(gpd.GeoDataFrame(pd.DataFrame([[np.nan,cp]],columns=['node','geometry']),geometry='geometry'),ignore_index=True)
#                         print('new node: '+','.join(str(c) for c in [cp.x, cp.y]))
                break
    return line_segs
        
def add_stops(row):
    global rows_processed
    rows_processed +=1
    print('Splitting long segments: %.1f' % (100 * rows_processed / total_rows) + '% processed', end='\r')
    line = row['geometry']
    dist = row['DISTANCE']
    if dist > 250:
        segs = math.ceil(dist / 200)
        seg_length = dist / segs
        return split_line(line, seg_length, segs)
    return None

unique_AB_to_split['new_segments'] = unique_AB_to_split.apply(add_stops, axis=1)

print('Splitting long segments: finished           ')
print(unique_nodes.shape[0])
# Out:
# Splitting long segments: finished
# 46503

# %%
total_rows = unique_AB_to_split.shape[0]
rows_processed = 0

def split_line(line, distance, segments):
    line_segs = [line]
    for i in range(segments - 1):
        line = line_segs[-1]
        line_segs = line_segs[:-1]
        coords = list(line.coords)
        for i, p in enumerate(coords):
            pd = line.project(Point(p))
            if pd == distance:
                line_segs += [LineString(coords[:i+1]), LineString(coords[i:])]
            if pd > distance:
                cp = line.interpolate(distance, )
                line_segs += [
                    LineString(coords[:i] + [(cp.x, cp.y)]),
                    LineString([(cp.x, cp.y)] + coords[i:])]
    return line_segs
        
def add_stops(row):
    global rows_processed
    rows_processed +=1
    print('Splitting long segments: %.1f' % (100 * rows_processed / total_rows) + '% processed', end='\r')
    line = row['geometry']
    dist = line.length
    if dist > 150:
        segs = math.ceil(dist / 150)
        seg_length = dist / segs
        return split_line(line, seg_length, segs)
    return None

unique_AB_to_split['new_segments'] = unique_AB_to_split.apply(add_stops, axis=1)

print('Splitting long segments: finished           ')
# Out:
# Splitting long segments: finished
# 46503

# %%
unique_AB_to_split = unique_AB_to_split.loc[unique_AB_to_split['new_segments'].notnull()]

unique_AB_to_split['STOPA'] = 1
unique_AB_to_split['STOPB'] = 1

unique_AB_to_split = unique_AB_to_split[['A','B','A_B','STOPA','STOPB','geometry']] \
    .merge(unique_AB_to_split['new_segments'].explode(), right_index = True, left_index = True) \
    .dropna() \
    .reset_index(drop = True)

unique_AB_to_split = unique_AB_to_split.drop(['geometry'], axis=1).rename(columns={'new_segments':'geometry'})
# Out:
# /Users/frankiemacbook/opt/miniconda3/envs/py3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
# unique_points = df_unique.drop_duplicates(subset=['A'])[['A','geometry']].rename(columns={'A':'node'})

# temp_B_points = df_unique.drop_duplicates(subset=['B'])[['B','geometry']].rename(columns={'B':'node'})

# unique_points = unique_points.append(temp_B_points.loc[~temp_B_points['node'].isin(unique_points['node'].to_list())])
# unique_points.geometry = unique_points.geometry.apply(lambda line: Point(line.coords[0]))
# unique_points = gpd.GeoDataFrame(unique_points, geometry='geometry')

# %%
max_node = df[['A','B']].max().max()

def insert_nodes(group):
    global max_node
    if group.shape[0] > 1:
        new_nodes = list(range(max_node+1,max_node+group.shape[0]))
        group['B'].iloc[:-1] = new_nodes
        group['A'].iloc[1:] = new_nodes
        max_node = max_node+group.shape[0]-1
    return group

unique_AB_to_split = unique_AB_to_split.groupby('A_B').apply(insert_nodes)

# %%
unique_AB_to_split
# Out:
#             A       B          A_B  STOPA  STOPB  \
# 0       10002  936234  10002_10190      1      1
# 1      936234  936235  10002_10190      1      1
# 2      936235  936236  10002_10190      1      1
# 3      936236  936237  10002_10190      1      1
# 4      936237   10190  10002_10190      1      1
# ...       ...     ...          ...    ...    ...
# 56618    9995  975227   9995_24174      1      1
# 56619  975227   24174   9995_24174      1      1
# 56620    9996  975228   9996_24311      1      1
# 56621  975228  975229   9996_24311      1      1
# 56622  975229   24311   9996_24311      1      1
#
#                                                 geometry
# 0      LINESTRING (345534.000 5815270.000, 345404.800...
# 1      LINESTRING (345404.800 5815139.800, 345275.600...
# 2      LINESTRING (345275.600 5815009.600, 345146.400...
# 3      LINESTRING (345146.400 5814879.400, 345017.200...
# 4      LINESTRING (345017.200 5814749.200, 344888.000...
# ...                                                  ...
# 56618  LINESTRING (347516.000 5816663.000, 347710.000...
# 56619  LINESTRING (347710.000 5816637.500, 347904.000...
# 56620  LINESTRING (347846.000 5816180.000, 347706.333...
# 56621  LINESTRING (347706.333 5816111.667, 347566.667...
# 56622  LINESTRING (347566.667 5816043.333, 347427.000...
#
# [56623 rows x 6 columns]

# %%
unique_nodes = unique_AB_to_split.drop_duplicates(subset=['A'])[['A','geometry']].rename(columns={'A':'node'})
unique_nodes.geometry = unique_nodes.geometry.apply(lambda line: Point(line.coords[0]))
temp_B_nodes = unique_AB_to_split.drop_duplicates(subset=['B'])[['B','geometry']].rename(columns={'B':'node'})
temp_B_nodes.geometry = temp_B_nodes.geometry.apply(lambda line: Point(line.coords[-1]))
unique_nodes = unique_nodes.append(temp_B_nodes.loc[~temp_B_nodes['node'].isin(unique_nodes['node'].to_list())])
unique_nodes = gpd.GeoDataFrame(unique_nodes, geometry='geometry')

unique_nodes = unique_nodes.sort_values('node')

unique_nodes
# Out:
#          node                        geometry
# 43903    7001  POINT (325194.000 5803164.000)
# 43906    7002  POINT (337874.000 5803155.000)
# 43908    7004  POINT (348811.000 5803118.000)
# 43913    7005  POINT (338246.000 5803111.000)
# 43919    7007  POINT (293931.000 5803099.000)
# ...       ...                             ...
# 56615  975225  POINT (348982.750 5817697.500)
# 56617  975226  POINT (347390.000 5816680.500)
# 56619  975227  POINT (347710.000 5816637.500)
# 56621  975228  POINT (347706.333 5816111.667)
# 56622  975229  POINT (347566.667 5816043.333)
#
# [50904 rows x 2 columns]

# %%
# Check for and drop duplicate geometries
# convert to wkb
unique_nodes["geometry"] = unique_nodes["geometry"].apply(lambda geom: geom.wkb)  
unique_nodes['reassign_node'] = unique_nodes['node']

group_list = []

for name, group in unique_nodes.groupby("geometry"):
    if group.shape[0] > 1:
        first_node = group.iloc[0]['node']
        group['reassign_node'] = first_node
    group_list.append(group)

unique_nodes = pd.concat(group_list, ignore_index=True)

# convert back to shapely geometry
unique_nodes["geometry"] = unique_nodes["geometry"].apply(lambda geom: shapely.wkb.loads(geom))
# Out:
# /Users/frankiemacbook/opt/miniconda3/envs/py3/lib/python3.8/site-packages/geopandas/geodataframe.py:1321: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")

# %%
unique_nodes
# Out:
#          node                        geometry  reassign_node
# 0        8745  POINT (327680.000 5760458.000)           8745
# 1      959670  POINT (344128.000 5806176.500)         959670
# 2      959674  POINT (344128.000 5806176.500)         959670
# 3       28428  POINT (327936.000 5812636.000)          28428
# 4        7065  POINT (328320.000 5802745.000)           7065
# ...       ...                             ...            ...
# 50899  966657  POINT (366270.500 5801312.000)         966589
# 50900  941944  POINT (366271.000 5784827.333)         941944
# 50901  969970  POINT (366271.000 5784827.333)         941944
# 50902  962373  POINT (577022.000 5813080.667)         962373
# 50903  962654  POINT (577022.000 5813080.667)         962373
#
# [50904 rows x 3 columns]

# %%
unique_AB_to_split = unique_AB_to_split.merge(unique_nodes[['node','reassign_node']], how='left', left_on='A', right_on='node', suffixes=('','_A'))
unique_AB_to_split = unique_AB_to_split.merge(unique_nodes[['node','reassign_node']], how='left', left_on='B', right_on='node', suffixes=('','_B'))

unique_AB_to_split['A'] = unique_AB_to_split['reassign_node']
unique_AB_to_split['B'] = unique_AB_to_split['reassign_node_B']
unique_AB_to_split = unique_AB_to_split.drop(['node','node_B','reassign_node','reassign_node_B'], axis=1)
# convert back to shapely geometry
# unique_nodes["geometry"] = unique_nodes["geometry"].apply(lambda geom: shapely.wkb.loads(geom))

# %%
# unique_nodes = unique_nodes.drop_duplicates(['reassign_node'])
# unique_nodes['node'] = unique_nodes['reassign_node']
# unique_nodes = unique_nodes.drop(['reassign_node'], axis=1)

# def closest_point(point):
#     distances = unique_nodes.distance(point).nsmallest(2)
#     distances = distances.loc[distances > 0]
#     nodes = unique_nodes.loc[distances.index,'node']
#     return [nodes.iloc[0], distances.iloc[0]]

# unique_nodes['nearest_node'] = unique_nodes['geometry'].apply(lambda row: pd.Series(closest_point(row)))

# %%
df_unique = df_unique.merge(unique_AB_to_split[['A_B','A','B','STOPA','STOPB','geometry']], how='left', on='A_B', suffixes=('','_merged')).reset_index(drop=True)

df_unique.loc[df_unique['A_merged'].notnull(),'A'] = df_unique.loc[df_unique['A_merged'].notnull(),'A_merged']
df_unique.loc[df_unique['A_merged'].notnull(),'B'] = df_unique.loc[df_unique['A_merged'].notnull(),'B_merged']
df_unique.loc[df_unique['A_merged'].notnull(),'STOPA'] = df_unique.loc[df_unique['A_merged'].notnull(),'STOPA_merged']
df_unique.loc[df_unique['A_merged'].notnull(),'STOPB'] = df_unique.loc[df_unique['A_merged'].notnull(),'STOPB_merged']
df_unique.loc[df_unique['A_merged'].notnull(),'geometry'] = df_unique.loc[df_unique['A_merged'].notnull(),'geometry_merged']
df_unique = df_unique.drop(['A_merged','B_merged','STOPA_merged','STOPB_merged','geometry_merged'], axis=1)

df_unique['A'] = df_unique['A'].apply(int)
df_unique['B'] = df_unique['B'].apply(int)

# %%
df_unique.loc[df_unique['A'] == df_unique['B']]
# Out:
# Empty DataFrame
# Columns: [A_B, A, B, STOPA, STOPB, LINKC_AM, BUS_SPD, DISTANCE, UNIQUE_ROUTE, UNIQUE_ROUTE_SEQ, LINKSEQ, mode, geometry]
# Index: []

# %%
lasts = df_unique.reset_index().groupby('UNIQUE_ROUTE').last().reset_index().set_index('index')
lasts['last'] = True

df_unique = df_unique.merge(lasts['last'], how='left', left_index=True, right_index=True)

# %%
df_unique.loc[((df_unique['STOPB'] == 1) & (~df_unique['LINKC_AM'].isin([18,20,25])) & (df_unique['BUS_SPD'] != 80)) | df_unique['last'], 'stop_flag'] = True

# %%
# distsum = 0
# total_rows = df_unique.shape[0]
# rows_processed = 0
# stopping_nodes = {}

# def find_nodes(row):
#     global distsum, stopping_nodes, rows_processed, start_node
#     a_node = row['A']
#     b_node = row['B']
#     route = row['UNIQUE_ROUTE']
#     rows_processed +=1
#     print('Finding nodes: %.1f' % (100 * rows_processed / total_rows) + '% processed', end='\r')
#     if distsum == 0:
#         stopping_nodes[a_node] = True
#         start_node = a_node
#         if rows_processed < total_rows:
#             if df_unique.loc[row.name+1,'UNIQUE_ROUTE'] == route:
#                 if start_node == df_unique.loc[row.name+1,'B']:
#                     stopping_nodes[b_node] = True
#                     return row
#     distsum += row['geometry'].length
#     if b_node in stopping_nodes:
#         distsum = 0
#         return row
#     if row['STOPB'] == 1:
#         if start_node == b_node:
#             return row
#         if rows_processed < total_rows:
#             if df_unique.loc[row.name+1,'UNIQUE_ROUTE'] == route:
#                 if distsum < 250:
#                     return row
#                 if (df_unique.loc[row.name+1,'B'] in stopping_nodes) and \
#                    (df_unique.loc[row.name+1,'geometry'].length < 200):
#                     return row
#         stopping_nodes[b_node] = True
#         distsum = 0
#     return row

# df_unique = df_unique.apply(lambda row: pd.Series(find_nodes(row)), axis=1)

# print('Finding nodes: finished           ')

# %%
distsum = 0
links = []
stops = []
total_rows = df_unique.shape[0]
rows_processed = 0

def consolidate_links_and_nodes(row):
    global distsum, links, stops, rows_processed
    a_node = row['A']
    b_node = row['B']
    stopa = 0
    stopb = 0
    totaldist = np.nan
    alllinks = np.nan
    allstops = np.nan
    rows_processed +=1
    print('Consolidating links and nodes: %.1f' % (100 * rows_processed / total_rows) + '% processed', end='\r')
    new_line = row['geometry']
    line_slice = new_line.coords
    if len(links) > 0:
        line_slice = new_line.coords[1:]
    links += [l for l in line_slice]
    if distsum == 0:
        stops.append((a_node,Point(links[0])))
        stopa = 1
    new_dist = new_line.length
    distsum += new_dist
    if row['stop_flag']:
        totaldist = distsum
        alllinks = LineString(links)
        stops.append((b_node,Point(links[-1])))
        stopb = 1
        allstops = stops
        distsum = 0
        links = []
        stops = []
    return [stopa, stopb, totaldist, alllinks, allstops, [Point(new_line.coords[0]),Point(new_line.coords[-1])], new_dist]

df_unique[['STOPA','STOPB','SEGDIST','SEGLINK','SEGSTOPS','LINKNODES','shape_dist_traveled']] = df_unique.apply(lambda row: pd.Series(consolidate_links_and_nodes(row)), axis=1)

print('Consolidating links and nodes: finished           ')
# Out:
# Consolidating links and nodes: finished

# %%
def expand_points(group):
    first_line = group.iloc[0]
    first_line['LINKNODES'] = first_line['LINKNODES'][0]
    first_line['shape_dist_traveled'] = 0
    group['LINKNODES'] = group['LINKNODES'].apply(lambda x: x[1])
    group['shape_dist_traveled'] = (group['shape_dist_traveled'].cumsum()*100).apply(round)/100
    group['LINKSEQ'] = group['LINKSEQ'] + 1
    return first_line.to_frame().T.append(group)

df_shapes = df_unique[['UNIQUE_ROUTE','LINKSEQ','LINKNODES','shape_dist_traveled']]
df_shapes = df_shapes.groupby('UNIQUE_ROUTE').apply(expand_points).reset_index(drop=True)

df_shapes = gpd.GeoDataFrame(df_shapes, geometry='LINKNODES', crs='epsg:20255').to_crs('epsg:4326')

df_shapes['shape_pt_lon'],df_shapes['shape_pt_lat'] = zip(*df_shapes['LINKNODES'].apply(lambda x: [x.x,x.y]))

df_shapes = df_shapes.rename({'LINKDIST':'shape_dist_traveled','LINKSEQ':'shape_pt_sequence'}, axis=1).drop(['LINKNODES'], axis=1)

# %%
df = df.drop(['A','B','STOPA','STOPB'], axis=1).merge(df_unique[['UNIQUE_ROUTE_SEQ','A','B','STOPA','STOPB','SEGDIST','SEGLINK','SEGSTOPS']], how='left', on='UNIQUE_ROUTE_SEQ')

df = df.loc[(df.STOPA == 1) | (df.STOPB == 1)].sort_values(['year','LINENO','PERIOD','LINKSEQ'])

df.loc[df['STOPA'] == 0]
# Out:
# Empty DataFrame
# Columns: [PERIOD, mode, LINENO, LINKSEQ, NAME, LONGNAME, year, YEAR_LINE_PERIOD, YEAR_LINE, A_B, LINKC_AM, DISTANCE, BUS_SPD, geometry, UNIQUE_ROUTE, UNIQUE_ROUTE_SEQ, A, B, STOPA, STOPB, SEGDIST, SEGLINK, SEGSTOPS]
# Index: []
#
# [0 rows x 23 columns]

# %%
df['STOPA_shift'] = df['STOPA'].shift()
df['A_shift'] = df['A'].shift()

firsts = df.groupby('NAME').first()
firsts.loc[firsts['STOPA'] == 0]
# Out:
# Empty DataFrame
# Columns: [PERIOD, mode, LINENO, LINKSEQ, LONGNAME, year, YEAR_LINE_PERIOD, YEAR_LINE, A_B, LINKC_AM, DISTANCE, BUS_SPD, geometry, UNIQUE_ROUTE, UNIQUE_ROUTE_SEQ, A, B, STOPA, STOPB, SEGDIST, SEGLINK, SEGSTOPS, STOPA_shift, A_shift]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['A'] = np.where(df['STOPA'] == 0, df['A_shift'], df['A'])
df['STOPA'] = np.where(df['STOPA'] == 0, df['STOPA_shift'], df['STOPA'])

df = df.loc[df.STOPB == 1].sort_values(['year','LINENO','PERIOD','LINKSEQ'])
df['A'] = df['A'].apply(int)
df['B'] = df['B'].apply(int)

df = df.drop(['LINKSEQ','UNIQUE_ROUTE_SEQ'],axis=1)

df.loc[df['A'] == df['B']]
# Out:
# Empty DataFrame
# Columns: [PERIOD, mode, LINENO, NAME, LONGNAME, year, YEAR_LINE_PERIOD, YEAR_LINE, A_B, LINKC_AM, DISTANCE, BUS_SPD, geometry, UNIQUE_ROUTE, A, B, STOPA, STOPB, SEGDIST, SEGLINK, SEGSTOPS, STOPA_shift, A_shift]
# Index: []
#
# [0 rows x 23 columns]

# %%
pt_reporting['Time Period'] = pt_reporting['Time Period'].apply(lambda x: x.split(' ')[0])
pt_reporting['YEAR_NAME_PERIOD'] = pt_reporting['year'] + '_' + pt_reporting['Short Name'] + "_" + pt_reporting['Time Period']

# %%
df['YEAR_NAME_PERIOD'] = df['year'] + '_' + df['NAME'] + "_" + df['PERIOD']
unique_speeds_headways = df.groupby('YEAR_NAME_PERIOD').first().reset_index()
unique_speeds_headways = unique_speeds_headways.merge(pt_reporting[['YEAR_NAME_PERIOD','Headway','Average Speed']], how='left', on='YEAR_NAME_PERIOD').drop('YEAR_NAME_PERIOD', axis=1)[['YEAR_LINE','year','LINENO','PERIOD','NAME','LONGNAME','mode','Headway','Average Speed','UNIQUE_ROUTE']]
unique_speeds_headways = unique_speeds_headways.rename({'LINENO':'id','NAME':'route','LONGNAME':'name','PERIOD':'period','Average Speed':'speed','Headway':'headway'}, axis=1)

# %%
unique_speeds_headways
# Out:
#        YEAR_LINE  year    id period       route  \
# 0       2018_305  2018   305     AM         109
# 1       2018_305  2018   305     IP         109
# 2       2018_305  2018   305     OP         109
# 3       2018_305  2018   305     PM         109
# 4         2018_2  2018     2     AM       11011
# ...          ...   ...   ...    ...         ...
# 31625  2051_1476  2051  1476     PM  WredstoneR
# 31626  2051_1475  2051  1475     AM   Wredstone
# 31627  2051_1475  2051  1475     IP   Wredstone
# 31628  2051_1475  2051  1475     OP   Wredstone
# 31629  2051_1475  2051  1475     PM   Wredstone
#
#                                           name   mode  headway  speed  \
# 0                    BOX HILL - PORT MELBOURNE   tram      7.5  15.42
# 1                    BOX HILL - PORT MELBOURNE   tram     10.0  16.24
# 2                    BOX HILL - PORT MELBOURNE   tram     12.0  16.54
# 3                    BOX HILL - PORT MELBOURNE   tram      7.5  15.98
# 4      Mernda - Flinders Street - All Stations  train     13.3  36.16
# ...                                        ...    ...      ...    ...
# 31625                  Sunbury - Redstone Hill    bus     40.0  20.09
# 31626                  Sunbury - Redstone Hill    bus     40.0  21.36
# 31627                  Sunbury - Redstone Hill    bus     40.0  21.54
# 31628                  Sunbury - Redstone Hill    bus     60.0  21.72
# 31629                  Sunbury - Redstone Hill    bus     40.0  19.01
#
#        UNIQUE_ROUTE
# 0              1457
# 1              1457
# 2              1457
# 3              1457
# 4               785
# ...             ...
# 31625           426
# 31626          1307
# 31627          1307
# 31628          1307
# 31629          1307
#
# [31630 rows x 10 columns]

# %%
pivot = pd.pivot_table(unique_speeds_headways, index=['YEAR_LINE'], columns=["period"], values=["headway","speed"], aggfunc=np.mean)
pivot.columns = ['_'.join(col).strip().lower() for col in pivot.columns.values]

# %%
speed_cols = ['speed_am','speed_ip','speed_pm','speed_op']
headway_cols = ['headway_am','headway_ip','headway_pm','headway_op']
unique_speeds_headways = unique_speeds_headways.merge(pivot.reset_index(), how='left', on='YEAR_LINE').groupby('YEAR_LINE').first().reset_index().replace(np.nan,0).drop('period',axis=1)

# %%
def fix_missing_speeds(row):
    for i in range(len(speed_cols)):
        if row[speed_cols[i]] == 0:
            row[speed_cols[i]] = row[speed_cols[(i+3) % 4]]
    return row

unique_speeds_headways = unique_speeds_headways.apply(fix_missing_speeds, axis=1)
unique_speeds_headways = unique_speeds_headways.loc[(unique_speeds_headways[headway_cols] != 0).any(1)]

# %%
def stop_nodes(group):
    global stop_list, link_list, dist_list, node_list, counter
    counter = 0
    link_list = []
    stop_list = []
    dist_list = []
    node_list = []
    group.apply(get_nodes, axis=1)
    return [list(zip(link_list, node_list, dist_list)), MultiLineString(link_list), stop_list]
    
def get_nodes(row):
    global stop_list, link_list, dist_list, node_list, counter
    link_list.append(row['SEGLINK'])
    node_list.append(str(row['A'])+'_'+str(row['B']))
    dist_list.append(row['SEGDIST'])
    if counter == 0:
        stop_list.append(row['SEGSTOPS'][0])
    stop_list.append(row['SEGSTOPS'][1])
    counter += 1
    
def number_segments(l):
    segs = ''
    for i in range(len(l)):
        segs += str(i)+','
    return segs[:-1]

stop_patterns = df.loc[df['YEAR_LINE_PERIOD'].isin(unique_routes['YEAR_LINE_PERIOD'].to_list())].groupby('UNIQUE_ROUTE').apply(stop_nodes).reset_index()
stop_patterns[['SEGMENTS','LINE','STOPPATTERN']] = pd.DataFrame(stop_patterns[0].tolist(), index=stop_patterns.index)
stop_patterns = stop_patterns.drop(0, axis=1)
stop_patterns['segments'] = stop_patterns['SEGMENTS'].apply(number_segments)

# %%
stop_patterns = unique_speeds_headways.merge(stop_patterns, how='left', on='UNIQUE_ROUTE')

# Replace non-ASCII characters
table = {0x2013: '-', 0x2014: '--', 0x00a7: 'sect. ', 0x00A0: ' '}
stop_patterns.loc[~stop_patterns['name'].apply(lambda string: string.isascii()),'name'] = stop_patterns.loc[~stop_patterns['name'].apply(lambda string: string.isascii()),'name'].apply(lambda string: string.translate(table))
stop_patterns.loc[~stop_patterns['name'].apply(lambda string: string.isascii()),'name']
# Out:
# Series([], Name: name, dtype: object)

# %%
route_output = stop_patterns.groupby('YEAR_LINE').first().reset_index()[['year','id','route','mode','name','LINE']]
route_output = route_output.rename({'LINE':'geometry','mode':'OPERATOR_N','route':'ROUTE_SHORT','name':'ROUTE_LONG','id':'ROUTE_ID'}, axis=1)
route_output['SHAPE_ID'] = route_output['ROUTE_ID']

route_output = gpd.GeoDataFrame(route_output[['year','SHAPE_ID','ROUTE_ID','ROUTE_SHORT','ROUTE_LONG','OPERATOR_N','geometry']], geometry='geometry', crs='epsg:20255').to_crs('epsg:4326')

# %%
routes = stop_patterns[['year','route','id','mode','name']+headway_cols+speed_cols+['segments']]

# %%
seg_expand = stop_patterns[['id','year','mode','route','name','UNIQUE_ROUTE']] \
    .merge(stop_patterns.SEGMENTS.explode(), right_index = True, left_index = True) \
    .dropna() \
    .sort_values(['year','id']) \
    .reset_index(drop = True)

# %%
seg_expand[['SEGMENT','NODES','route_dist']] = pd.DataFrame(seg_expand['SEGMENTS'].tolist(), index=seg_expand.index)
seg_expand = gpd.GeoDataFrame(seg_expand.drop('SEGMENTS', axis=1).rename(columns={'SEGMENT':'geometry'}), geometry='geometry', crs='epsg:20255').to_crs('epsg:4326')

# %%
seg_expand['NODES'] = seg_expand['NODES'].apply(lambda x: x.split('_'))
seg_expand[['stop1','stop2']] = pd.DataFrame(seg_expand['NODES'].tolist(), index=seg_expand.index)
seg_expand = seg_expand.drop('NODES', axis=1)
seg_expand['stop1N'] = seg_expand['stop1'].apply(str)
seg_expand['stop2N'] = seg_expand['stop2'].apply(str)
seg_expand = seg_expand.rename({'id':'routes'}, axis=1)
seg_expand['id'] = seg_expand.groupby(['year','routes']).cumcount()

# %%
(seg_expand['stop1'] == seg_expand['stop2']).to_frame().groupby(0)[0].count()
# Out:
# 0
# False    962461
# Name: 0, dtype: int64

# %%
sp_expand = stop_patterns[['id','year','mode','route','name']] \
    .merge(stop_patterns.STOPPATTERN.explode(), right_index = True, left_index = True) \
    .dropna() \
    .sort_values(['year','id']) \
    .reset_index(drop = True)

# %%
sp_expand[['id','STOPPATTERN']] = pd.DataFrame(sp_expand['STOPPATTERN'].tolist(), index=sp_expand.index)
sp_expand['name'] = sp_expand['id'].apply(str)
sp_expand = gpd.GeoDataFrame(sp_expand.rename(columns={'STOPPATTERN':'geometry'}), geometry='geometry', crs='epsg:20255').to_crs('epsg:4326')
sp_expand = sp_expand.drop_duplicates(subset=['id']).drop(['year','route','mode'], axis=1).reset_index(drop=True)

# %%
end_processing_time = time.time()
pre_processing_time = end_processing_time - start_time

# from importlib import reload
# reload(create_gtfs_from_basicinfo)

# print('Saving network shapefiles')
# if not os.path.isdir('output/Network'):
#     os.mkdir('output/Network')
# route_output.to_file('output/Network/VITM_'+year+'_segments.shp')
# sp_expand.to_file('output/Network/VITM_'+year+'_stops.shp')

if not os.path.isdir('input/temp'):
    os.mkdir('input/temp')

modes = {'vline':'1','train':'2','tram':'3','bus':'4','skybus':'11'}

for year in years:
    print('Generating GTFS outputs for '+year+' reference case\n')
    for mode in all_modes:
        if mode not in modes:
            print("'"+mode+"' not a valid mode")
            continue
#         if mode not in seg_expand['mode'].unique().to_list():
#             continue
    #     if mode != 'train':
    #         continue
        sys.argv = ['', '--year', year, '--service', mode]

        if not os.path.isdir('output/'+modes[mode]):
            os.mkdir('output/'+modes[mode])

        stop_ids = seg_expand.loc[(seg_expand['mode'] == mode) & (seg_expand['year'] == year), ['stop1','stop2']].values
        stop_ids = list(dict.fromkeys([int(val) for sublist in stop_ids for val in sublist]))
        
        unique_route_ids = list(seg_expand.loc[(seg_expand['mode'] == mode) & (seg_expand['year'] == year), 'UNIQUE_ROUTE'].unique())

        sp_expand.loc[sp_expand['id'].isin(stop_ids)].to_file('input/temp/VITM_stops.shp')
        seg_expand.loc[(seg_expand['mode'] == mode) & (seg_expand['year'] == year)].drop('UNIQUE_ROUTE',axis=1).to_file('input/temp/VITM_segments.shp')
        routes.loc[(routes['mode'] == mode) & (routes['year'] == year)].to_csv('input/temp/VITM_routes.csv', index=False, sep=';')
        df_shapes.loc[df_shapes['UNIQUE_ROUTE'].isin(unique_route_ids)].drop('UNIQUE_ROUTE',axis=1).to_csv('input/temp/shapes.txt', index=False)

        create_gtfs_from_basicinfo.run()

    print('\nCreating output/VITM_'+year+'_GTFS.zip...\n')
    # create a ZipFile object
    with zipfile.ZipFile('output/VITM_'+year+'_GTFS.zip', 'w', zipfile.ZIP_DEFLATED) as zipObj:
        # Iterate over all the files in directory
        for folder_id in list(modes.values()):
            if os.path.isdir('output/'+folder_id):
                for folderName, subfolders, filenames in os.walk('output/'+folder_id):
                    for filename in filenames:
                        #create complete filepath of file in directory
                        filePath = os.path.join(folderName, filename)
                        # Add file to zip
                        zipObj.write(filePath, os.path.join(folder_id, filename))
                shutil.rmtree('output/'+folder_id)
    
print('Cleaning up temp files...')
shutil.rmtree('input/temp')

print('Done')

total_time = time.time() - start_time

print('Pre-processing time: %.1f minutes' % (pre_processing_time / 60))
print('Total time: %.1f minutes' % (total_time / 60))

os.system("printf '\a'")
# Out:
# Generating GTFS outputs for 2018 reference case
#
# Creating GTFS feed for bus
# Processing routes 0 to 907
# About to save complete timetable to file output/4/google_transit.zip ...
# ...finished writing to file output/4/google_transit.zip.
# Creating GTFS feed for skybus
# Processing routes 0 to 17
# About to save complete timetable to file output/11/google_transit.zip ...
# ...finished writing to file output/11/google_transit.zip.
# Creating GTFS feed for train
# Processing routes 0 to 267
# About to save complete timetable to file output/2/google_transit.zip ...
# ...finished writing to file output/2/google_transit.zip.
# Creating GTFS feed for tram
# Processing routes 0 to 45
# About to save complete timetable to file output/3/google_transit.zip ...
# ...finished writing to file output/3/google_transit.zip.
# Creating GTFS feed for vline
# Processing routes 0 to 95
# About to save complete timetable to file output/1/google_transit.zip ...
# ...finished writing to file output/1/google_transit.zip.
#
# Creating output/VITM_2018_GTFS.zip...
#
# Generating GTFS outputs for 2026 reference case
#
# Creating GTFS feed for bus
# Processing routes 0 to 1258
# About to save complete timetable to file output/4/google_transit.zip ...
#  column route_long_name
# Invalid value b'pearcedale - frankston' in field b'route_long_name'
# b'The same combination of route_short_name and route_long_name shouldn\'t be used for more than one route, as it is for the for the two routes with IDs "894" and "892".'
# Trip 4400452 has 7 consecutive stop times all with the same arrival/departure time: b'07:00:00'.
# Trip 4400453 has 7 consecutive stop times all with the same arrival/departure time: b'07:40:00'.
# Trip 4400454 has 7 consecutive stop times all with the same arrival/departure time: b'08:20:00'.
# Trip 4400455 has 7 consecutive stop times all with the same arrival/departure time: b'09:00:00'.
# Trip 4400456 has 7 consecutive stop times all with the same arrival/departure time: b'09:40:00'.
# Trip 4400457 has 7 consecutive stop times all with the same arrival/departure time: b'10:20:00'.
# Trip 4400458 has 7 consecutive stop times all with the same arrival/departure time: b'11:00:00'.
# Trip 4400459 has 7 consecutive stop times all with the same arrival/departure time: b'11:40:00'.
# Trip 4400460 has 7 consecutive stop times all with the same arrival/departure time: b'12:20:00'.
# Trip 4400461 has 7 consecutive stop times all with the same arrival/departure time: b'13:00:00'.
# Trip 4400462 has 7 consecutive stop times all with the same arrival/departure time: b'13:40:00'.
# Trip 4400463 has 7 consecutive stop times all with the same arrival/departure time: b'14:20:00'.
# Trip 4400464 has 7 consecutive stop times all with the same arrival/departure time: b'15:00:00'.
# Trip 4400465 has 7 consecutive stop times all with the same arrival/departure time: b'15:40:00'.
# Trip 4400466 has 7 consecutive stop times all with the same arrival/departure time: b'16:20:00'.
# Trip 4400467 has 7 consecutive stop times all with the same arrival/departure time: b'17:00:00'.
# Trip 4400468 has 7 consecutive stop times all with the same arrival/departure time: b'17:40:00'.
# Trip 4400469 has 7 consecutive stop times all with the same arrival/departure time: b'18:00:00'.
# Trip 4400470 has 7 consecutive stop times all with the same arrival/departure time: b'19:00:00'.
# Trip 4400471 has 7 consecutive stop times all with the same arrival/departure time: b'20:00:00'.
# Trip 4400472 has 7 consecutive stop times all with the same arrival/departure time: b'21:00:00'.
# Trip 4400473 has 7 consecutive stop times all with the same arrival/departure time: b'22:00:00'.
# Trip 4400474 has 7 consecutive stop times all with the same arrival/departure time: b'23:00:00'.
# Trip 4400475 has 7 consecutive stop times all with the same arrival/departure time: b'00:00:00'.
# Trip 4400476 has 7 consecutive stop times all with the same arrival/departure time: b'01:00:00'.
# Trip 4400477 has 7 consecutive stop times all with the same arrival/departure time: b'02:00:00'.
# Trip 4400478 has 7 consecutive stop times all with the same arrival/departure time: b'03:00:00'.
# Trip 4400479 has 7 consecutive stop times all with the same arrival/departure time: b'04:00:00'.
# Trip 4400480 has 7 consecutive stop times all with the same arrival/departure time: b'05:00:00'.
# Trip 4400481 has 7 consecutive stop times all with the same arrival/departure time: b'06:00:00'.
# Trip 4400482 has 7 consecutive stop times all with the same arrival/departure time: b'07:23:33'.
# Trip 4400483 has 7 consecutive stop times all with the same arrival/departure time: b'08:03:33'.
# Trip 4400484 has 7 consecutive stop times all with the same arrival/departure time: b'08:43:33'.
# Trip 4400485 has 7 consecutive stop times all with the same arrival/departure time: b'09:23:31'.
# Trip 4400486 has 7 consecutive stop times all with the same arrival/departure time: b'10:03:31'.
# Trip 4400487 has 7 consecutive stop times all with the same arrival/departure time: b'10:43:31'.
# Trip 4400488 has 7 consecutive stop times all with the same arrival/departure time: b'11:23:31'.
# Trip 4400489 has 7 consecutive stop times all with the same arrival/departure time: b'12:03:31'.
# Trip 4400490 has 7 consecutive stop times all with the same arrival/departure time: b'12:43:31'.
# Trip 4400491 has 7 consecutive stop times all with the same arrival/departure time: b'13:23:31'.
# Trip 4400492 has 7 consecutive stop times all with the same arrival/departure time: b'14:03:31'.
# Trip 4400493 has 7 consecutive stop times all with the same arrival/departure time: b'14:43:31'.
# Trip 4400494 has 7 consecutive stop times all with the same arrival/departure time: b'15:23:33'.
# Trip 4400495 has 7 consecutive stop times all with the same arrival/departure time: b'16:03:33'.
# Trip 4400496 has 7 consecutive stop times all with the same arrival/departure time: b'16:43:33'.
# Trip 4400497 has 7 consecutive stop times all with the same arrival/departure time: b'17:23:33'.
# Trip 4400498 has 7 consecutive stop times all with the same arrival/departure time: b'18:03:33'.
# Trip 4400499 has 7 consecutive stop times all with the same arrival/departure time: b'18:23:27'.
# Trip 4400500 has 7 consecutive stop times all with the same arrival/departure time: b'19:23:27'.
# Trip 4400501 has 7 consecutive stop times all with the same arrival/departure time: b'20:23:27'.
# Trip 4400502 has 7 consecutive stop times all with the same arrival/departure time: b'21:23:27'.
# Trip 4400503 has 7 consecutive stop times all with the same arrival/departure time: b'22:23:27'.
# Trip 4400504 has 7 consecutive stop times all with the same arrival/departure time: b'23:23:27'.
# Trip 4400505 has 7 consecutive stop times all with the same arrival/departure time: b'00:23:27'.
# Trip 4400506 has 7 consecutive stop times all with the same arrival/departure time: b'01:23:27'.
# Trip 4400507 has 7 consecutive stop times all with the same arrival/departure time: b'02:23:27'.
# Trip 4400508 has 7 consecutive stop times all with the same arrival/departure time: b'03:23:27'.
# Trip 4400509 has 7 consecutive stop times all with the same arrival/departure time: b'04:23:27'.
# Trip 4400510 has 7 consecutive stop times all with the same arrival/departure time: b'05:23:27'.
# Trip 4400511 has 7 consecutive stop times all with the same arrival/departure time: b'06:23:27'.
# Trip 4406393 has 49 consecutive stop times all with the same arrival/departure time: b'07:14:31'.
# Trip 4406393 has 12 consecutive stop times all with the same arrival/departure time: b'07:14:42'.
# Trip 4406393 has 15 consecutive stop times all with the same arrival/departure time: b'07:14:49'.
# Trip 4406393 has 20 consecutive stop times all with the same arrival/departure time: b'07:14:51'.
# Trip 4406394 has 49 consecutive stop times all with the same arrival/departure time: b'07:34:31'.
# Trip 4406394 has 12 consecutive stop times all with the same arrival/departure time: b'07:34:42'.
# Trip 4406394 has 15 consecutive stop times all with the same arrival/departure time: b'07:34:49'.
# Trip 4406394 has 20 consecutive stop times all with the same arrival/departure time: b'07:34:51'.
# Trip 4406395 has 49 consecutive stop times all with the same arrival/departure time: b'07:54:31'.
# Trip 4406395 has 12 consecutive stop times all with the same arrival/departure time: b'07:54:42'.
# Trip 4406395 has 15 consecutive stop times all with the same arrival/departure time: b'07:54:49'.
# Trip 4406395 has 20 consecutive stop times all with the same arrival/departure time: b'07:54:51'.
# Trip 4406396 has 49 consecutive stop times all with the same arrival/departure time: b'08:14:31'.
# Trip 4406396 has 12 consecutive stop times all with the same arrival/departure time: b'08:14:42'.
# Trip 4406396 has 15 consecutive stop times all with the same arrival/departure time: b'08:14:49'.
# Trip 4406396 has 20 consecutive stop times all with the same arrival/departure time: b'08:14:51'.
# Trip 4406397 has 49 consecutive stop times all with the same arrival/departure time: b'08:34:31'.
# Trip 4406397 has 12 consecutive stop times all with the same arrival/departure time: b'08:34:42'.
# Trip 4406397 has 15 consecutive stop times all with the same arrival/departure time: b'08:34:49'.
# Trip 4406397 has 20 consecutive stop times all with the same arrival/departure time: b'08:34:51'.
# Trip 4406398 has 49 consecutive stop times all with the same arrival/departure time: b'08:54:31'.
# Trip 4406398 has 12 consecutive stop times all with the same arrival/departure time: b'08:54:42'.
# Trip 4406398 has 15 consecutive stop times all with the same arrival/departure time: b'08:54:49'.
# Trip 4406398 has 20 consecutive stop times all with the same arrival/departure time: b'08:54:51'.
# Trip 4406399 has 49 consecutive stop times all with the same arrival/departure time: b'09:14:31'.
# Trip 4406399 has 12 consecutive stop times all with the same arrival/departure time: b'09:14:42'.
# Trip 4406399 has 15 consecutive stop times all with the same arrival/departure time: b'09:14:49'.
# Trip 4406399 has 20 consecutive stop times all with the same arrival/departure time: b'09:14:51'.
# Trip 4406400 has 49 consecutive stop times all with the same arrival/departure time: b'09:54:31'.
# Trip 4406400 has 12 consecutive stop times all with the same arrival/departure time: b'09:54:42'.
# Trip 4406400 has 15 consecutive stop times all with the same arrival/departure time: b'09:54:49'.
# Trip 4406400 has 20 consecutive stop times all with the same arrival/departure time: b'09:54:51'.
# Trip 4406401 has 49 consecutive stop times all with the same arrival/departure time: b'10:34:31'.
# Trip 4406401 has 12 consecutive stop times all with the same arrival/departure time: b'10:34:42'.
# Trip 4406401 has 15 consecutive stop times all with the same arrival/departure time: b'10:34:49'.
# Trip 4406401 has 20 consecutive stop times all with the same arrival/departure time: b'10:34:51'.
# Trip 4406402 has 49 consecutive stop times all with the same arrival/departure time: b'11:14:31'.
# Trip 4406402 has 12 consecutive stop times all with the same arrival/departure time: b'11:14:42'.
# Trip 4406402 has 15 consecutive stop times all with the same arrival/departure time: b'11:14:49'.
# Trip 4406402 has 20 consecutive stop times all with the same arrival/departure time: b'11:14:51'.
# Trip 4406403 has 49 consecutive stop times all with the same arrival/departure time: b'11:54:31'.
# Trip 4406403 has 12 consecutive stop times all with the same arrival/departure time: b'11:54:42'.
# Trip 4406403 has 15 consecutive stop times all with the same arrival/departure time: b'11:54:49'.
# Trip 4406403 has 20 consecutive stop times all with the same arrival/departure time: b'11:54:51'.
# Trip 4406404 has 49 consecutive stop times all with the same arrival/departure time: b'12:34:31'.
# Trip 4406404 has 12 consecutive stop times all with the same arrival/departure time: b'12:34:42'.
# Trip 4406404 has 15 consecutive stop times all with the same arrival/departure time: b'12:34:49'.
# Trip 4406404 has 20 consecutive stop times all with the same arrival/departure time: b'12:34:51'.
# Trip 4406405 has 49 consecutive stop times all with the same arrival/departure time: b'13:14:31'.
# Trip 4406405 has 12 consecutive stop times all with the same arrival/departure time: b'13:14:42'.
# Trip 4406405 has 15 consecutive stop times all with the same arrival/departure time: b'13:14:49'.
# Trip 4406405 has 20 consecutive stop times all with the same arrival/departure time: b'13:14:51'.
# Trip 4406406 has 49 consecutive stop times all with the same arrival/departure time: b'13:54:31'.
# Trip 4406406 has 12 consecutive stop times all with the same arrival/departure time: b'13:54:42'.
# Trip 4406406 has 15 consecutive stop times all with the same arrival/departure time: b'13:54:49'.
# Trip 4406406 has 20 consecutive stop times all with the same arrival/departure time: b'13:54:51'.
# Trip 4406407 has 49 consecutive stop times all with the same arrival/departure time: b'14:34:31'.
# Trip 4406407 has 12 consecutive stop times all with the same arrival/departure time: b'14:34:42'.
# Trip 4406407 has 15 consecutive stop times all with the same arrival/departure time: b'14:34:49'.
# Trip 4406407 has 20 consecutive stop times all with the same arrival/departure time: b'14:34:51'.
# Trip 4406408 has 49 consecutive stop times all with the same arrival/departure time: b'15:14:59'.
# Trip 4406408 has 12 consecutive stop times all with the same arrival/departure time: b'15:15:11'.
# Trip 4406408 has 15 consecutive stop times all with the same arrival/departure time: b'15:15:19'.
# Trip 4406408 has 20 consecutive stop times all with the same arrival/departure time: b'15:15:21'.
# Trip 4406409 has 49 consecutive stop times all with the same arrival/departure time: b'15:34:59'.
# Trip 4406409 has 12 consecutive stop times all with the same arrival/departure time: b'15:35:11'.
# Trip 4406409 has 15 consecutive stop times all with the same arrival/departure time: b'15:35:19'.
# Trip 4406409 has 20 consecutive stop times all with the same arrival/departure time: b'15:35:21'.
# Trip 4406410 has 49 consecutive stop times all with the same arrival/departure time: b'15:54:59'.
# Trip 4406410 has 12 consecutive stop times all with the same arrival/departure time: b'15:55:11'.
# Trip 4406410 has 15 consecutive stop times all with the same arrival/departure time: b'15:55:19'.
# Trip 4406410 has 20 consecutive stop times all with the same arrival/departure time: b'15:55:21'.
# Trip 4406411 has 49 consecutive stop times all with the same arrival/departure time: b'16:14:59'.
# Trip 4406411 has 12 consecutive stop times all with the same arrival/departure time: b'16:15:11'.
# Trip 4406411 has 15 consecutive stop times all with the same arrival/departure time: b'16:15:19'.
# Trip 4406411 has 20 consecutive stop times all with the same arrival/departure time: b'16:15:21'.
# Trip 4406412 has 49 consecutive stop times all with the same arrival/departure time: b'16:34:59'.
# Trip 4406412 has 12 consecutive stop times all with the same arrival/departure time: b'16:35:11'.
# Trip 4406412 has 15 consecutive stop times all with the same arrival/departure time: b'16:35:19'.
# Trip 4406412 has 20 consecutive stop times all with the same arrival/departure time: b'16:35:21'.
# Trip 4406413 has 49 consecutive stop times all with the same arrival/departure time: b'16:54:59'.
# Trip 4406413 has 12 consecutive stop times all with the same arrival/departure time: b'16:55:11'.
# Trip 4406413 has 15 consecutive stop times all with the same arrival/departure time: b'16:55:19'.
# Trip 4406413 has 20 consecutive stop times all with the same arrival/departure time: b'16:55:21'.
# Trip 4406414 has 49 consecutive stop times all with the same arrival/departure time: b'17:14:59'.
# Trip 4406414 has 12 consecutive stop times all with the same arrival/departure time: b'17:15:11'.
# Trip 4406414 has 15 consecutive stop times all with the same arrival/departure time: b'17:15:19'.
# Trip 4406414 has 20 consecutive stop times all with the same arrival/departure time: b'17:15:21'.
# Trip 4406415 has 49 consecutive stop times all with the same arrival/departure time: b'17:34:59'.
# Trip 4406415 has 12 consecutive stop times all with the same arrival/departure time: b'17:35:11'.
# Trip 4406415 has 15 consecutive stop times all with the same arrival/departure time: b'17:35:19'.
# Trip 4406415 has 20 consecutive stop times all with the same arrival/departure time: b'17:35:21'.
# Trip 4406416 has 49 consecutive stop times all with the same arrival/departure time: b'17:54:59'.
# Trip 4406416 has 12 consecutive stop times all with the same arrival/departure time: b'17:55:11'.
# Trip 4406416 has 15 consecutive stop times all with the same arrival/departure time: b'17:55:19'.
# Trip 4406416 has 20 consecutive stop times all with the same arrival/departure time: b'17:55:21'.
# Trip 4406417 has 49 consecutive stop times all with the same arrival/departure time: b'18:14:29'.
# Trip 4406417 has 12 consecutive stop times all with the same arrival/departure time: b'18:14:40'.
# Trip 4406417 has 15 consecutive stop times all with the same arrival/departure time: b'18:14:47'.
# Trip 4406417 has 20 consecutive stop times all with the same arrival/departure time: b'18:14:49'.
# Trip 4406418 has 49 consecutive stop times all with the same arrival/departure time: b'18:54:29'.
# Trip 4406418 has 12 consecutive stop times all with the same arrival/departure time: b'18:54:40'.
# Trip 4406418 has 15 consecutive stop times all with the same arrival/departure time: b'18:54:47'.
# Trip 4406418 has 20 consecutive stop times all with the same arrival/departure time: b'18:54:49'.
# Trip 4406419 has 49 consecutive stop times all with the same arrival/departure time: b'19:34:29'.
# Trip 4406419 has 12 consecutive stop times all with the same arrival/departure time: b'19:34:40'.
# Trip 4406419 has 15 consecutive stop times all with the same arrival/departure time: b'19:34:47'.
# Trip 4406419 has 20 consecutive stop times all with the same arrival/departure time: b'19:34:49'.
# Trip 4406420 has 49 consecutive stop times all with the same arrival/departure time: b'20:14:29'.
# Trip 4406420 has 12 consecutive stop times all with the same arrival/departure time: b'20:14:40'.
# Trip 4406420 has 15 consecutive stop times all with the same arrival/departure time: b'20:14:47'.
# Trip 4406420 has 20 consecutive stop times all with the same arrival/departure time: b'20:14:49'.
# Trip 4406421 has 49 consecutive stop times all with the same arrival/departure time: b'20:54:29'.
# Trip 4406421 has 12 consecutive stop times all with the same arrival/departure time: b'20:54:40'.
# Trip 4406421 has 15 consecutive stop times all with the same arrival/departure time: b'20:54:47'.
# Trip 4406421 has 20 consecutive stop times all with the same arrival/departure time: b'20:54:49'.
# Trip 4406422 has 49 consecutive stop times all with the same arrival/departure time: b'21:34:29'.
# Trip 4406422 has 12 consecutive stop times all with the same arrival/departure time: b'21:34:40'.
# Trip 4406422 has 15 consecutive stop times all with the same arrival/departure time: b'21:34:47'.
# Trip 4406422 has 20 consecutive stop times all with the same arrival/departure time: b'21:34:49'.
# Trip 4406423 has 49 consecutive stop times all with the same arrival/departure time: b'22:14:29'.
# Trip 4406423 has 12 consecutive stop times all with the same arrival/departure time: b'22:14:40'.
# Trip 4406423 has 15 consecutive stop times all with the same arrival/departure time: b'22:14:47'.
# Trip 4406423 has 20 consecutive stop times all with the same arrival/departure time: b'22:14:49'.
# Trip 4406424 has 49 consecutive stop times all with the same arrival/departure time: b'22:54:29'.
# Trip 4406424 has 12 consecutive stop times all with the same arrival/departure time: b'22:54:40'.
# Trip 4406424 has 15 consecutive stop times all with the same arrival/departure time: b'22:54:47'.
# Trip 4406424 has 20 consecutive stop times all with the same arrival/departure time: b'22:54:49'.
# Trip 4406425 has 49 consecutive stop times all with the same arrival/departure time: b'23:34:29'.
# Trip 4406425 has 12 consecutive stop times all with the same arrival/departure time: b'23:34:40'.
# Trip 4406425 has 15 consecutive stop times all with the same arrival/departure time: b'23:34:47'.
# Trip 4406425 has 20 consecutive stop times all with the same arrival/departure time: b'23:34:49'.
# Trip 4406426 has 49 consecutive stop times all with the same arrival/departure time: b'00:14:29'.
# Trip 4406426 has 12 consecutive stop times all with the same arrival/departure time: b'00:14:40'.
# Trip 4406426 has 15 consecutive stop times all with the same arrival/departure time: b'00:14:47'.
# Trip 4406426 has 20 consecutive stop times all with the same arrival/departure time: b'00:14:49'.
# Trip 4406427 has 49 consecutive stop times all with the same arrival/departure time: b'00:54:29'.
# Trip 4406427 has 12 consecutive stop times all with the same arrival/departure time: b'00:54:40'.
# Trip 4406427 has 15 consecutive stop times all with the same arrival/departure time: b'00:54:47'.
# Trip 4406427 has 20 consecutive stop times all with the same arrival/departure time: b'00:54:49'.
# Trip 4406428 has 49 consecutive stop times all with the same arrival/departure time: b'01:34:29'.
# Trip 4406428 has 12 consecutive stop times all with the same arrival/departure time: b'01:34:40'.
# Trip 4406428 has 15 consecutive stop times all with the same arrival/departure time: b'01:34:47'.
# Trip 4406428 has 20 consecutive stop times all with the same arrival/departure time: b'01:34:49'.
# Trip 4406429 has 49 consecutive stop times all with the same arrival/departure time: b'02:14:29'.
# Trip 4406429 has 12 consecutive stop times all with the same arrival/departure time: b'02:14:40'.
# Trip 4406429 has 15 consecutive stop times all with the same arrival/departure time: b'02:14:47'.
# Trip 4406429 has 20 consecutive stop times all with the same arrival/departure time: b'02:14:49'.
# Trip 4406430 has 49 consecutive stop times all with the same arrival/departure time: b'02:54:29'.
# Trip 4406430 has 12 consecutive stop times all with the same arrival/departure time: b'02:54:40'.
# Trip 4406430 has 15 consecutive stop times all with the same arrival/departure time: b'02:54:47'.
# Trip 4406430 has 20 consecutive stop times all with the same arrival/departure time: b'02:54:49'.
# Trip 4406431 has 49 consecutive stop times all with the same arrival/departure time: b'03:34:29'.
# Trip 4406431 has 12 consecutive stop times all with the same arrival/departure time: b'03:34:40'.
# Trip 4406431 has 15 consecutive stop times all with the same arrival/departure time: b'03:34:47'.
# Trip 4406431 has 20 consecutive stop times all with the same arrival/departure time: b'03:34:49'.
# Trip 4406432 has 49 consecutive stop times all with the same arrival/departure time: b'04:14:29'.
# Trip 4406432 has 12 consecutive stop times all with the same arrival/departure time: b'04:14:40'.
# Trip 4406432 has 15 consecutive stop times all with the same arrival/departure time: b'04:14:47'.
# Trip 4406432 has 20 consecutive stop times all with the same arrival/departure time: b'04:14:49'.
# Trip 4406433 has 49 consecutive stop times all with the same arrival/departure time: b'04:54:29'.
# Trip 4406433 has 12 consecutive stop times all with the same arrival/departure time: b'04:54:40'.
# Trip 4406433 has 15 consecutive stop times all with the same arrival/departure time: b'04:54:47'.
# Trip 4406433 has 20 consecutive stop times all with the same arrival/departure time: b'04:54:49'.
# Trip 4406434 has 49 consecutive stop times all with the same arrival/departure time: b'05:34:29'.
# Trip 4406434 has 12 consecutive stop times all with the same arrival/departure time: b'05:34:40'.
# Trip 4406434 has 15 consecutive stop times all with the same arrival/departure time: b'05:34:47'.
# Trip 4406434 has 20 consecutive stop times all with the same arrival/departure time: b'05:34:49'.
# Trip 4406435 has 49 consecutive stop times all with the same arrival/departure time: b'06:14:29'.
# Trip 4406435 has 12 consecutive stop times all with the same arrival/departure time: b'06:14:40'.
# Trip 4406435 has 15 consecutive stop times all with the same arrival/departure time: b'06:14:47'.
# Trip 4406435 has 20 consecutive stop times all with the same arrival/departure time: b'06:14:49'.
# Trip 4406436 has 49 consecutive stop times all with the same arrival/departure time: b'06:54:29'.
# Trip 4406436 has 12 consecutive stop times all with the same arrival/departure time: b'06:54:40'.
# Trip 4406436 has 15 consecutive stop times all with the same arrival/departure time: b'06:54:47'.
# Trip 4406436 has 20 consecutive stop times all with the same arrival/departure time: b'06:54:49'.
# Trip 4406437 has 20 consecutive stop times all with the same arrival/departure time: b'07:19:23'.
# Trip 4406437 has 15 consecutive stop times all with the same arrival/departure time: b'07:19:25'.
# Trip 4406437 has 12 consecutive stop times all with the same arrival/departure time: b'07:19:33'.
# Trip 4406437 has 49 consecutive stop times all with the same arrival/departure time: b'07:19:45'.
# Trip 4406438 has 20 consecutive stop times all with the same arrival/departure time: b'07:39:23'.
# Trip 4406438 has 15 consecutive stop times all with the same arrival/departure time: b'07:39:25'.
# Trip 4406438 has 12 consecutive stop times all with the same arrival/departure time: b'07:39:33'.
# Trip 4406438 has 49 consecutive stop times all with the same arrival/departure time: b'07:39:45'.
# Trip 4406439 has 20 consecutive stop times all with the same arrival/departure time: b'07:59:23'.
# Trip 4406439 has 15 consecutive stop times all with the same arrival/departure time: b'07:59:25'.
# Trip 4406439 has 12 consecutive stop times all with the same arrival/departure time: b'07:59:33'.
# Trip 4406439 has 49 consecutive stop times all with the same arrival/departure time: b'07:59:45'.
# Trip 4406440 has 20 consecutive stop times all with the same arrival/departure time: b'08:19:23'.
# Trip 4406440 has 15 consecutive stop times all with the same arrival/departure time: b'08:19:25'.
# Trip 4406440 has 12 consecutive stop times all with the same arrival/departure time: b'08:19:33'.
# Trip 4406440 has 49 consecutive stop times all with the same arrival/departure time: b'08:19:45'.
# Trip 4406441 has 20 consecutive stop times all with the same arrival/departure time: b'08:39:23'.
# Trip 4406441 has 15 consecutive stop times all with the same arrival/departure time: b'08:39:25'.
# Trip 4406441 has 12 consecutive stop times all with the same arrival/departure time: b'08:39:33'.
# Trip 4406441 has 49 consecutive stop times all with the same arrival/departure time: b'08:39:45'.
# Trip 4406442 has 20 consecutive stop times all with the same arrival/departure time: b'08:59:23'.
# Trip 4406442 has 15 consecutive stop times all with the same arrival/departure time: b'08:59:25'.
# Trip 4406442 has 12 consecutive stop times all with the same arrival/departure time: b'08:59:33'.
# Trip 4406442 has 49 consecutive stop times all with the same arrival/departure time: b'08:59:45'.
# Trip 4406443 has 20 consecutive stop times all with the same arrival/departure time: b'09:18:52'.
# Trip 4406443 has 15 consecutive stop times all with the same arrival/departure time: b'09:18:54'.
# Trip 4406443 has 12 consecutive stop times all with the same arrival/departure time: b'09:19:01'.
# Trip 4406443 has 49 consecutive stop times all with the same arrival/departure time: b'09:19:12'.
# Trip 4406444 has 20 consecutive stop times all with the same arrival/departure time: b'09:58:52'.
# Trip 4406444 has 15 consecutive stop times all with the same arrival/departure time: b'09:58:54'.
# Trip 4406444 has 12 consecutive stop times all with the same arrival/departure time: b'09:59:01'.
# Trip 4406444 has 49 consecutive stop times all with the same arrival/departure time: b'09:59:12'.
# Trip 4406445 has 20 consecutive stop times all with the same arrival/departure time: b'10:38:52'.
# Trip 4406445 has 15 consecutive stop times all with the same arrival/departure time: b'10:38:54'.
# Trip 4406445 has 12 consecutive stop times all with the same arrival/departure time: b'10:39:01'.
# Trip 4406445 has 49 consecutive stop times all with the same arrival/departure time: b'10:39:12'.
# Trip 4406446 has 20 consecutive stop times all with the same arrival/departure time: b'11:18:52'.
# Trip 4406446 has 15 consecutive stop times all with the same arrival/departure time: b'11:18:54'.
# Trip 4406446 has 12 consecutive stop times all with the same arrival/departure time: b'11:19:01'.
# Trip 4406446 has 49 consecutive stop times all with the same arrival/departure time: b'11:19:12'.
# Trip 4406447 has 20 consecutive stop times all with the same arrival/departure time: b'11:58:52'.
# Trip 4406447 has 15 consecutive stop times all with the same arrival/departure time: b'11:58:54'.
# Trip 4406447 has 12 consecutive stop times all with the same arrival/departure time: b'11:59:01'.
# Trip 4406447 has 49 consecutive stop times all with the same arrival/departure time: b'11:59:12'.
# Trip 4406448 has 20 consecutive stop times all with the same arrival/departure time: b'12:38:52'.
# Trip 4406448 has 15 consecutive stop times all with the same arrival/departure time: b'12:38:54'.
# Trip 4406448 has 12 consecutive stop times all with the same arrival/departure time: b'12:39:01'.
# Trip 4406448 has 49 consecutive stop times all with the same arrival/departure time: b'12:39:12'.
# Trip 4406449 has 20 consecutive stop times all with the same arrival/departure time: b'13:18:52'.
# Trip 4406449 has 15 consecutive stop times all with the same arrival/departure time: b'13:18:54'.
# Trip 4406449 has 12 consecutive stop times all with the same arrival/departure time: b'13:19:01'.
# Trip 4406449 has 49 consecutive stop times all with the same arrival/departure time: b'13:19:12'.
# Trip 4406450 has 20 consecutive stop times all with the same arrival/departure time: b'13:58:52'.
# Trip 4406450 has 15 consecutive stop times all with the same arrival/departure time: b'13:58:54'.
# Trip 4406450 has 12 consecutive stop times all with the same arrival/departure time: b'13:59:01'.
# Trip 4406450 has 49 consecutive stop times all with the same arrival/departure time: b'13:59:12'.
# Trip 4406451 has 20 consecutive stop times all with the same arrival/departure time: b'14:38:52'.
# Trip 4406451 has 15 consecutive stop times all with the same arrival/departure time: b'14:38:54'.
# Trip 4406451 has 12 consecutive stop times all with the same arrival/departure time: b'14:39:01'.
# Trip 4406451 has 49 consecutive stop times all with the same arrival/departure time: b'14:39:12'.
# Trip 4406452 has 20 consecutive stop times all with the same arrival/departure time: b'15:18:54'.
# Trip 4406452 has 15 consecutive stop times all with the same arrival/departure time: b'15:18:56'.
# Trip 4406452 has 12 consecutive stop times all with the same arrival/departure time: b'15:19:03'.
# Trip 4406452 has 49 consecutive stop times all with the same arrival/departure time: b'15:19:14'.
# Trip 4406453 has 20 consecutive stop times all with the same arrival/departure time: b'15:38:54'.
# Trip 4406453 has 15 consecutive stop times all with the same arrival/departure time: b'15:38:56'.
# Trip 4406453 has 12 consecutive stop times all with the same arrival/departure time: b'15:39:03'.
# Trip 4406453 has 49 consecutive stop times all with the same arrival/departure time: b'15:39:14'.
# Trip 4406454 has 20 consecutive stop times all with the same arrival/departure time: b'15:58:54'.
# Trip 4406454 has 15 consecutive stop times all with the same arrival/departure time: b'15:58:56'.
# Trip 4406454 has 12 consecutive stop times all with the same arrival/departure time: b'15:59:03'.
# Trip 4406454 has 49 consecutive stop times all with the same arrival/departure time: b'15:59:14'.
# Trip 4406455 has 20 consecutive stop times all with the same arrival/departure time: b'16:18:54'.
# Trip 4406455 has 15 consecutive stop times all with the same arrival/departure time: b'16:18:56'.
# Trip 4406455 has 12 consecutive stop times all with the same arrival/departure time: b'16:19:03'.
# Trip 4406455 has 49 consecutive stop times all with the same arrival/departure time: b'16:19:14'.
# Trip 4406456 has 20 consecutive stop times all with the same arrival/departure time: b'16:38:54'.
# Trip 4406456 has 15 consecutive stop times all with the same arrival/departure time: b'16:38:56'.
# Trip 4406456 has 12 consecutive stop times all with the same arrival/departure time: b'16:39:03'.
# Trip 4406456 has 49 consecutive stop times all with the same arrival/departure time: b'16:39:14'.
# Trip 4406457 has 20 consecutive stop times all with the same arrival/departure time: b'16:58:54'.
# Trip 4406457 has 15 consecutive stop times all with the same arrival/departure time: b'16:58:56'.
# Trip 4406457 has 12 consecutive stop times all with the same arrival/departure time: b'16:59:03'.
# Trip 4406457 has 49 consecutive stop times all with the same arrival/departure time: b'16:59:14'.
# Trip 4406458 has 20 consecutive stop times all with the same arrival/departure time: b'17:18:54'.
# Trip 4406458 has 15 consecutive stop times all with the same arrival/departure time: b'17:18:56'.
# Trip 4406458 has 12 consecutive stop times all with the same arrival/departure time: b'17:19:03'.
# Trip 4406458 has 49 consecutive stop times all with the same arrival/departure time: b'17:19:14'.
# Trip 4406459 has 20 consecutive stop times all with the same arrival/departure time: b'17:38:54'.
# Trip 4406459 has 15 consecutive stop times all with the same arrival/departure time: b'17:38:56'.
# Trip 4406459 has 12 consecutive stop times all with the same arrival/departure time: b'17:39:03'.
# Trip 4406459 has 49 consecutive stop times all with the same arrival/departure time: b'17:39:14'.
# Trip 4406460 has 20 consecutive stop times all with the same arrival/departure time: b'17:58:54'.
# Trip 4406460 has 15 consecutive stop times all with the same arrival/departure time: b'17:58:56'.
# Trip 4406460 has 12 consecutive stop times all with the same arrival/departure time: b'17:59:03'.
# Trip 4406460 has 49 consecutive stop times all with the same arrival/departure time: b'17:59:14'.
# Trip 4406461 has 20 consecutive stop times all with the same arrival/departure time: b'18:18:49'.
# Trip 4406461 has 15 consecutive stop times all with the same arrival/departure time: b'18:18:51'.
# Trip 4406461 has 12 consecutive stop times all with the same arrival/departure time: b'18:18:58'.
# Trip 4406461 has 49 consecutive stop times all with the same arrival/departure time: b'18:19:09'.
# Trip 4406462 has 20 consecutive stop times all with the same arrival/departure time: b'18:58:49'.
# Trip 4406462 has 15 consecutive stop times all with the same arrival/departure time: b'18:58:51'.
# Trip 4406462 has 12 consecutive stop times all with the same arrival/departure time: b'18:58:58'.
# Trip 4406462 has 49 consecutive stop times all with the same arrival/departure time: b'18:59:09'.
# Trip 4406463 has 20 consecutive stop times all with the same arrival/departure time: b'19:38:49'.
# Trip 4406463 has 15 consecutive stop times all with the same arrival/departure time: b'19:38:51'.
# Trip 4406463 has 12 consecutive stop times all with the same arrival/departure time: b'19:38:58'.
# Trip 4406463 has 49 consecutive stop times all with the same arrival/departure time: b'19:39:09'.
# Trip 4406464 has 20 consecutive stop times all with the same arrival/departure time: b'20:18:49'.
# Trip 4406464 has 15 consecutive stop times all with the same arrival/departure time: b'20:18:51'.
# Trip 4406464 has 12 consecutive stop times all with the same arrival/departure time: b'20:18:58'.
# Trip 4406464 has 49 consecutive stop times all with the same arrival/departure time: b'20:19:09'.
# Trip 4406465 has 20 consecutive stop times all with the same arrival/departure time: b'20:58:49'.
# Trip 4406465 has 15 consecutive stop times all with the same arrival/departure time: b'20:58:51'.
# Trip 4406465 has 12 consecutive stop times all with the same arrival/departure time: b'20:58:58'.
# Trip 4406465 has 49 consecutive stop times all with the same arrival/departure time: b'20:59:09'.
# Trip 4406466 has 20 consecutive stop times all with the same arrival/departure time: b'21:38:49'.
# Trip 4406466 has 15 consecutive stop times all with the same arrival/departure time: b'21:38:51'.
# Trip 4406466 has 12 consecutive stop times all with the same arrival/departure time: b'21:38:58'.
# Trip 4406466 has 49 consecutive stop times all with the same arrival/departure time: b'21:39:09'.
# Trip 4406467 has 20 consecutive stop times all with the same arrival/departure time: b'22:18:49'.
# Trip 4406467 has 15 consecutive stop times all with the same arrival/departure time: b'22:18:51'.
# Trip 4406467 has 12 consecutive stop times all with the same arrival/departure time: b'22:18:58'.
# Trip 4406467 has 49 consecutive stop times all with the same arrival/departure time: b'22:19:09'.
# Trip 4406468 has 20 consecutive stop times all with the same arrival/departure time: b'22:58:49'.
# Trip 4406468 has 15 consecutive stop times all with the same arrival/departure time: b'22:58:51'.
# Trip 4406468 has 12 consecutive stop times all with the same arrival/departure time: b'22:58:58'.
# Trip 4406468 has 49 consecutive stop times all with the same arrival/departure time: b'22:59:09'.
# Trip 4406469 has 20 consecutive stop times all with the same arrival/departure time: b'23:38:49'.
# Trip 4406469 has 15 consecutive stop times all with the same arrival/departure time: b'23:38:51'.
# Trip 4406469 has 12 consecutive stop times all with the same arrival/departure time: b'23:38:58'.
# Trip 4406469 has 49 consecutive stop times all with the same arrival/departure time: b'23:39:09'.
# Trip 4406470 has 20 consecutive stop times all with the same arrival/departure time: b'00:18:49'.
# Trip 4406470 has 15 consecutive stop times all with the same arrival/departure time: b'00:18:51'.
# Trip 4406470 has 12 consecutive stop times all with the same arrival/departure time: b'00:18:58'.
# Trip 4406470 has 49 consecutive stop times all with the same arrival/departure time: b'00:19:09'.
# Trip 4406471 has 20 consecutive stop times all with the same arrival/departure time: b'00:58:49'.
# Trip 4406471 has 15 consecutive stop times all with the same arrival/departure time: b'00:58:51'.
# Trip 4406471 has 12 consecutive stop times all with the same arrival/departure time: b'00:58:58'.
# Trip 4406471 has 49 consecutive stop times all with the same arrival/departure time: b'00:59:09'.
# Trip 4406472 has 20 consecutive stop times all with the same arrival/departure time: b'01:38:49'.
# Trip 4406472 has 15 consecutive stop times all with the same arrival/departure time: b'01:38:51'.
# Trip 4406472 has 12 consecutive stop times all with the same arrival/departure time: b'01:38:58'.
# Trip 4406472 has 49 consecutive stop times all with the same arrival/departure time: b'01:39:09'.
# Trip 4406473 has 20 consecutive stop times all with the same arrival/departure time: b'02:18:49'.
# Trip 4406473 has 15 consecutive stop times all with the same arrival/departure time: b'02:18:51'.
# Trip 4406473 has 12 consecutive stop times all with the same arrival/departure time: b'02:18:58'.
# Trip 4406473 has 49 consecutive stop times all with the same arrival/departure time: b'02:19:09'.
# Trip 4406474 has 20 consecutive stop times all with the same arrival/departure time: b'02:58:49'.
# Trip 4406474 has 15 consecutive stop times all with the same arrival/departure time: b'02:58:51'.
# Trip 4406474 has 12 consecutive stop times all with the same arrival/departure time: b'02:58:58'.
# Trip 4406474 has 49 consecutive stop times all with the same arrival/departure time: b'02:59:09'.
# Trip 4406475 has 20 consecutive stop times all with the same arrival/departure time: b'03:38:49'.
# Trip 4406475 has 15 consecutive stop times all with the same arrival/departure time: b'03:38:51'.
# Trip 4406475 has 12 consecutive stop times all with the same arrival/departure time: b'03:38:58'.
# Trip 4406475 has 49 consecutive stop times all with the same arrival/departure time: b'03:39:09'.
# Trip 4406476 has 20 consecutive stop times all with the same arrival/departure time: b'04:18:49'.
# Trip 4406476 has 15 consecutive stop times all with the same arrival/departure time: b'04:18:51'.
# Trip 4406476 has 12 consecutive stop times all with the same arrival/departure time: b'04:18:58'.
# Trip 4406476 has 49 consecutive stop times all with the same arrival/departure time: b'04:19:09'.
# Trip 4406477 has 20 consecutive stop times all with the same arrival/departure time: b'04:58:49'.
# Trip 4406477 has 15 consecutive stop times all with the same arrival/departure time: b'04:58:51'.
# Trip 4406477 has 12 consecutive stop times all with the same arrival/departure time: b'04:58:58'.
# Trip 4406477 has 49 consecutive stop times all with the same arrival/departure time: b'04:59:09'.
# Trip 4406478 has 20 consecutive stop times all with the same arrival/departure time: b'05:38:49'.
# Trip 4406478 has 15 consecutive stop times all with the same arrival/departure time: b'05:38:51'.
# Trip 4406478 has 12 consecutive stop times all with the same arrival/departure time: b'05:38:58'.
# Trip 4406478 has 49 consecutive stop times all with the same arrival/departure time: b'05:39:09'.
# Trip 4406479 has 20 consecutive stop times all with the same arrival/departure time: b'06:18:49'.
# Trip 4406479 has 15 consecutive stop times all with the same arrival/departure time: b'06:18:51'.
# Trip 4406479 has 12 consecutive stop times all with the same arrival/departure time: b'06:18:58'.
# Trip 4406479 has 49 consecutive stop times all with the same arrival/departure time: b'06:19:09'.
# Trip 4406480 has 20 consecutive stop times all with the same arrival/departure time: b'06:58:49'.
# Trip 4406480 has 15 consecutive stop times all with the same arrival/departure time: b'06:58:51'.
# Trip 4406480 has 12 consecutive stop times all with the same arrival/departure time: b'06:58:58'.
# Trip 4406480 has 49 consecutive stop times all with the same arrival/departure time: b'06:59:09'.
# Trip 4439042 has 17 consecutive stop times all with the same arrival/departure time: b'07:27:07'.
# Trip 4439043 has 17 consecutive stop times all with the same arrival/departure time: b'07:47:07'.
# Trip 4439044 has 17 consecutive stop times all with the same arrival/departure time: b'08:07:07'.
# Trip 4439045 has 17 consecutive stop times all with the same arrival/departure time: b'08:27:07'.
# Trip 4439046 has 17 consecutive stop times all with the same arrival/departure time: b'08:47:07'.
# Trip 4439047 has 17 consecutive stop times all with the same arrival/departure time: b'09:07:07'.
# Trip 4439048 has 17 consecutive stop times all with the same arrival/departure time: b'09:27:07'.
# Trip 4439049 has 17 consecutive stop times all with the same arrival/departure time: b'09:47:07'.
# Trip 4439050 has 17 consecutive stop times all with the same arrival/departure time: b'10:07:07'.
# Trip 4439051 has 17 consecutive stop times all with the same arrival/departure time: b'10:27:07'.
# Trip 4439052 has 17 consecutive stop times all with the same arrival/departure time: b'10:47:07'.
# Trip 4439053 has 17 consecutive stop times all with the same arrival/departure time: b'11:07:07'.
# Trip 4439054 has 17 consecutive stop times all with the same arrival/departure time: b'11:27:07'.
# Trip 4439055 has 17 consecutive stop times all with the same arrival/departure time: b'11:47:07'.
# Trip 4439056 has 17 consecutive stop times all with the same arrival/departure time: b'12:07:07'.
# Trip 4439057 has 17 consecutive stop times all with the same arrival/departure time: b'12:27:07'.
# Trip 4439058 has 17 consecutive stop times all with the same arrival/departure time: b'12:47:07'.
# Trip 4439059 has 17 consecutive stop times all with the same arrival/departure time: b'13:07:07'.
# Trip 4439060 has 17 consecutive stop times all with the same arrival/departure time: b'13:27:07'.
# Trip 4439061 has 17 consecutive stop times all with the same arrival/departure time: b'13:47:07'.
# Trip 4439062 has 17 consecutive stop times all with the same arrival/departure time: b'14:07:07'.
# Trip 4439063 has 17 consecutive stop times all with the same arrival/departure time: b'14:27:07'.
# Trip 4439064 has 17 consecutive stop times all with the same arrival/departure time: b'14:47:07'.
# Trip 4439065 has 17 consecutive stop times all with the same arrival/departure time: b'15:07:07'.
# Trip 4439066 has 17 consecutive stop times all with the same arrival/departure time: b'15:27:07'.
# Trip 4439067 has 17 consecutive stop times all with the same arrival/departure time: b'15:47:07'.
# Trip 4439068 has 17 consecutive stop times all with the same arrival/departure time: b'16:07:07'.
# Trip 4439069 has 17 consecutive stop times all with the same arrival/departure time: b'16:27:07'.
# Trip 4439070 has 17 consecutive stop times all with the same arrival/departure time: b'16:47:07'.
# Trip 4439071 has 17 consecutive stop times all with the same arrival/departure time: b'17:07:07'.
# Trip 4439072 has 17 consecutive stop times all with the same arrival/departure time: b'17:27:07'.
# Trip 4439073 has 17 consecutive stop times all with the same arrival/departure time: b'17:47:07'.
# Trip 4439074 has 17 consecutive stop times all with the same arrival/departure time: b'18:07:07'.
# Trip 4439075 has 17 consecutive stop times all with the same arrival/departure time: b'18:27:07'.
# Trip 4439076 has 17 consecutive stop times all with the same arrival/departure time: b'18:47:07'.
# Trip 4439077 has 17 consecutive stop times all with the same arrival/departure time: b'19:07:07'.
# Trip 4439078 has 17 consecutive stop times all with the same arrival/departure time: b'19:27:07'.
# Trip 4439079 has 17 consecutive stop times all with the same arrival/departure time: b'19:47:07'.
# Trip 4439080 has 17 consecutive stop times all with the same arrival/departure time: b'20:07:07'.
# Trip 4439081 has 17 consecutive stop times all with the same arrival/departure time: b'20:27:07'.
# Trip 4439082 has 17 consecutive stop times all with the same arrival/departure time: b'20:47:07'.
# Trip 4439083 has 17 consecutive stop times all with the same arrival/departure time: b'21:07:07'.
# Trip 4439084 has 17 consecutive stop times all with the same arrival/departure time: b'21:27:07'.
# Trip 4439085 has 17 consecutive stop times all with the same arrival/departure time: b'21:47:07'.
# Trip 4439086 has 17 consecutive stop times all with the same arrival/departure time: b'22:07:07'.
# Trip 4439087 has 17 consecutive stop times all with the same arrival/departure time: b'22:27:07'.
# Trip 4439088 has 17 consecutive stop times all with the same arrival/departure time: b'22:47:07'.
# Trip 4439089 has 17 consecutive stop times all with the same arrival/departure time: b'23:07:07'.
# Trip 4439090 has 17 consecutive stop times all with the same arrival/departure time: b'23:27:07'.
# Trip 4439091 has 17 consecutive stop times all with the same arrival/departure time: b'23:47:07'.
# Trip 4439092 has 17 consecutive stop times all with the same arrival/departure time: b'24:07:07'.
# Trip 4439093 has 17 consecutive stop times all with the same arrival/departure time: b'00:27:07'.
# Trip 4439094 has 17 consecutive stop times all with the same arrival/departure time: b'00:47:07'.
# Trip 4439095 has 17 consecutive stop times all with the same arrival/departure time: b'01:07:07'.
# Trip 4439096 has 17 consecutive stop times all with the same arrival/departure time: b'01:27:07'.
# Trip 4439097 has 17 consecutive stop times all with the same arrival/departure time: b'01:47:07'.
# Trip 4439098 has 17 consecutive stop times all with the same arrival/departure time: b'02:07:07'.
# Trip 4439099 has 17 consecutive stop times all with the same arrival/departure time: b'02:27:07'.
# Trip 4439100 has 17 consecutive stop times all with the same arrival/departure time: b'02:47:07'.
# Trip 4439101 has 17 consecutive stop times all with the same arrival/departure time: b'03:07:07'.
# Trip 4439102 has 17 consecutive stop times all with the same arrival/departure time: b'03:27:07'.
# Trip 4439103 has 17 consecutive stop times all with the same arrival/departure time: b'03:47:07'.
# Trip 4439104 has 17 consecutive stop times all with the same arrival/departure time: b'04:07:07'.
# ...
# Trip 4441110 has 17 consecutive stop times all with the same arrival/departure time: b'18:27:07'.
# Trip 4441111 has 17 consecutive stop times all with the same arrival/departure time: b'18:47:07'.
# Trip 4441112 has 17 consecutive stop times all with the same arrival/departure time: b'19:07:07'.
# Trip 4441113 has 17 consecutive stop times all with the same arrival/departure time: b'19:27:07'.
# Trip 4441114 has 17 consecutive stop times all with the same arrival/departure time: b'19:47:07'.
# Trip 4441115 has 17 consecutive stop times all with the same arrival/departure time: b'20:07:07'.
# Trip 4441116 has 17 consecutive stop times all with the same arrival/departure time: b'20:27:07'.
# Trip 4441117 has 17 consecutive stop times all with the same arrival/departure time: b'20:47:07'.
# Trip 4441118 has 17 consecutive stop times all with the same arrival/departure time: b'21:07:07'.
# Trip 4441119 has 17 consecutive stop times all with the same arrival/departure time: b'21:27:07'.
# Trip 4441120 has 17 consecutive stop times all with the same arrival/departure time: b'21:47:07'.
# Trip 4441121 has 17 consecutive stop times all with the same arrival/departure time: b'22:07:07'.
# Trip 4441122 has 17 consecutive stop times all with the same arrival/departure time: b'22:27:07'.
# Trip 4441123 has 17 consecutive stop times all with the same arrival/departure time: b'22:47:07'.
# Trip 4441124 has 17 consecutive stop times all with the same arrival/departure time: b'23:07:07'.
# Trip 4441125 has 17 consecutive stop times all with the same arrival/departure time: b'23:27:07'.
# Trip 4441126 has 17 consecutive stop times all with the same arrival/departure time: b'23:47:07'.
# Trip 4441127 has 17 consecutive stop times all with the same arrival/departure time: b'24:07:07'.
# Trip 4441128 has 17 consecutive stop times all with the same arrival/departure time: b'00:27:07'.
# Trip 4441129 has 17 consecutive stop times all with the same arrival/departure time: b'00:47:07'.
# Trip 4441130 has 17 consecutive stop times all with the same arrival/departure time: b'01:07:07'.
# Trip 4441131 has 17 consecutive stop times all with the same arrival/departure time: b'01:27:07'.
# Trip 4441132 has 17 consecutive stop times all with the same arrival/departure time: b'01:47:07'.
# Trip 4441133 has 17 consecutive stop times all with the same arrival/departure time: b'02:07:07'.
# Trip 4441134 has 17 consecutive stop times all with the same arrival/departure time: b'02:27:07'.
# Trip 4441135 has 17 consecutive stop times all with the same arrival/departure time: b'02:47:07'.
# Trip 4441136 has 17 consecutive stop times all with the same arrival/departure time: b'03:07:07'.
# Trip 4441137 has 17 consecutive stop times all with the same arrival/departure time: b'03:27:07'.
# Trip 4441138 has 17 consecutive stop times all with the same arrival/departure time: b'03:47:07'.
# Trip 4441139 has 17 consecutive stop times all with the same arrival/departure time: b'04:07:07'.
# Trip 4441140 has 17 consecutive stop times all with the same arrival/departure time: b'04:27:07'.
# Trip 4441141 has 17 consecutive stop times all with the same arrival/departure time: b'04:47:07'.
# Trip 4441142 has 17 consecutive stop times all with the same arrival/departure time: b'05:07:07'.
# Trip 4441143 has 17 consecutive stop times all with the same arrival/departure time: b'05:27:07'.
# Trip 4441144 has 17 consecutive stop times all with the same arrival/departure time: b'05:47:07'.
# Trip 4441145 has 17 consecutive stop times all with the same arrival/departure time: b'06:07:07'.
# Trip 4441146 has 17 consecutive stop times all with the same arrival/departure time: b'06:27:07'.
# Trip 4441147 has 17 consecutive stop times all with the same arrival/departure time: b'06:47:07'.
# Trip 4441148 has 17 consecutive stop times all with the same arrival/departure time: b'07:07:07'.
# Trip 4441149 has 17 consecutive stop times all with the same arrival/departure time: b'07:03:52'.
# Trip 4441150 has 17 consecutive stop times all with the same arrival/departure time: b'07:23:52'.
# Trip 4441151 has 17 consecutive stop times all with the same arrival/departure time: b'07:43:52'.
# Trip 4441152 has 17 consecutive stop times all with the same arrival/departure time: b'08:03:52'.
# Trip 4441153 has 17 consecutive stop times all with the same arrival/departure time: b'08:23:52'.
# Trip 4441154 has 17 consecutive stop times all with the same arrival/departure time: b'08:43:52'.
# Trip 4441155 has 17 consecutive stop times all with the same arrival/departure time: b'09:03:52'.
# Trip 4441156 has 17 consecutive stop times all with the same arrival/departure time: b'09:23:52'.
# Trip 4441157 has 17 consecutive stop times all with the same arrival/departure time: b'09:43:52'.
# Trip 4441158 has 17 consecutive stop times all with the same arrival/departure time: b'10:03:52'.
# Trip 4441159 has 17 consecutive stop times all with the same arrival/departure time: b'10:23:52'.
# Trip 4441160 has 17 consecutive stop times all with the same arrival/departure time: b'10:43:52'.
# Trip 4441161 has 17 consecutive stop times all with the same arrival/departure time: b'11:03:52'.
# Trip 4441162 has 17 consecutive stop times all with the same arrival/departure time: b'11:23:52'.
# Trip 4441163 has 17 consecutive stop times all with the same arrival/departure time: b'11:43:52'.
# Trip 4441164 has 17 consecutive stop times all with the same arrival/departure time: b'12:03:52'.
# Trip 4441165 has 17 consecutive stop times all with the same arrival/departure time: b'12:23:52'.
# Trip 4441166 has 17 consecutive stop times all with the same arrival/departure time: b'12:43:52'.
# Trip 4441167 has 17 consecutive stop times all with the same arrival/departure time: b'13:03:52'.
# Trip 4441168 has 17 consecutive stop times all with the same arrival/departure time: b'13:23:52'.
# Trip 4441169 has 17 consecutive stop times all with the same arrival/departure time: b'13:43:52'.
# Trip 4441170 has 17 consecutive stop times all with the same arrival/departure time: b'14:03:52'.
# Trip 4441171 has 17 consecutive stop times all with the same arrival/departure time: b'14:23:52'.
# Trip 4441172 has 17 consecutive stop times all with the same arrival/departure time: b'14:43:52'.
# Trip 4441173 has 17 consecutive stop times all with the same arrival/departure time: b'15:03:52'.
# Trip 4441174 has 17 consecutive stop times all with the same arrival/departure time: b'15:23:52'.
# Trip 4441175 has 17 consecutive stop times all with the same arrival/departure time: b'15:43:52'.
# Trip 4441176 has 17 consecutive stop times all with the same arrival/departure time: b'16:03:52'.
# Trip 4441177 has 17 consecutive stop times all with the same arrival/departure time: b'16:23:52'.
# Trip 4441178 has 17 consecutive stop times all with the same arrival/departure time: b'16:43:52'.
# Trip 4441179 has 17 consecutive stop times all with the same arrival/departure time: b'17:03:52'.
# Trip 4441180 has 17 consecutive stop times all with the same arrival/departure time: b'17:23:52'.
# Trip 4441181 has 17 consecutive stop times all with the same arrival/departure time: b'17:43:52'.
# Trip 4441182 has 17 consecutive stop times all with the same arrival/departure time: b'18:03:52'.
# Trip 4441183 has 17 consecutive stop times all with the same arrival/departure time: b'18:23:52'.
# Trip 4441184 has 17 consecutive stop times all with the same arrival/departure time: b'18:43:52'.
# Trip 4441185 has 17 consecutive stop times all with the same arrival/departure time: b'19:03:52'.
# Trip 4441186 has 17 consecutive stop times all with the same arrival/departure time: b'19:23:52'.
# Trip 4441187 has 17 consecutive stop times all with the same arrival/departure time: b'19:43:52'.
# Trip 4441188 has 17 consecutive stop times all with the same arrival/departure time: b'20:03:52'.
# Trip 4441189 has 17 consecutive stop times all with the same arrival/departure time: b'20:23:52'.
# Trip 4441190 has 17 consecutive stop times all with the same arrival/departure time: b'20:43:52'.
# Trip 4441191 has 17 consecutive stop times all with the same arrival/departure time: b'21:03:52'.
# Trip 4441192 has 17 consecutive stop times all with the same arrival/departure time: b'21:23:52'.
# Trip 4441193 has 17 consecutive stop times all with the same arrival/departure time: b'21:43:52'.
# Trip 4441194 has 17 consecutive stop times all with the same arrival/departure time: b'22:03:52'.
# Trip 4441195 has 17 consecutive stop times all with the same arrival/departure time: b'22:23:52'.
# Trip 4441196 has 17 consecutive stop times all with the same arrival/departure time: b'22:43:52'.
# Trip 4441197 has 17 consecutive stop times all with the same arrival/departure time: b'23:03:52'.
# Trip 4441198 has 17 consecutive stop times all with the same arrival/departure time: b'23:23:52'.
# Trip 4441199 has 17 consecutive stop times all with the same arrival/departure time: b'23:43:52'.
# Trip 4441200 has 17 consecutive stop times all with the same arrival/departure time: b'00:03:52'.
# Trip 4441201 has 17 consecutive stop times all with the same arrival/departure time: b'00:23:52'.
# Trip 4441202 has 17 consecutive stop times all with the same arrival/departure time: b'00:43:52'.
# Trip 4441203 has 17 consecutive stop times all with the same arrival/departure time: b'01:03:52'.
# Trip 4441204 has 17 consecutive stop times all with the same arrival/departure time: b'01:23:52'.
# Trip 4441205 has 17 consecutive stop times all with the same arrival/departure time: b'01:43:52'.
# Trip 4441206 has 17 consecutive stop times all with the same arrival/departure time: b'02:03:52'.
# Trip 4441207 has 17 consecutive stop times all with the same arrival/departure time: b'02:23:52'.
# Trip 4441208 has 17 consecutive stop times all with the same arrival/departure time: b'02:43:52'.
# Trip 4441209 has 17 consecutive stop times all with the same arrival/departure time: b'03:03:52'.
# Trip 4441210 has 17 consecutive stop times all with the same arrival/departure time: b'03:23:52'.
# Trip 4441211 has 17 consecutive stop times all with the same arrival/departure time: b'03:43:52'.
# Trip 4441212 has 17 consecutive stop times all with the same arrival/departure time: b'04:03:52'.
# Trip 4441213 has 17 consecutive stop times all with the same arrival/departure time: b'04:23:52'.
# Trip 4441214 has 17 consecutive stop times all with the same arrival/departure time: b'04:43:52'.
# Trip 4441215 has 17 consecutive stop times all with the same arrival/departure time: b'05:03:52'.
# Trip 4441216 has 17 consecutive stop times all with the same arrival/departure time: b'05:23:52'.
# Trip 4441217 has 17 consecutive stop times all with the same arrival/departure time: b'05:43:52'.
# Trip 4441218 has 17 consecutive stop times all with the same arrival/departure time: b'06:03:52'.
# Trip 4441219 has 17 consecutive stop times all with the same arrival/departure time: b'06:23:52'.
# Trip 4441220 has 17 consecutive stop times all with the same arrival/departure time: b'06:43:52'.
# ...finished writing to file output/4/google_transit.zip.
# Creating GTFS feed for skybus
# Processing routes 0 to 17
# About to save complete timetable to file output/11/google_transit.zip ...
# ...finished writing to file output/11/google_transit.zip.
# Creating GTFS feed for train
# Processing routes 0 to 53
# About to save complete timetable to file output/2/google_transit.zip ...
# ...finished writing to file output/2/google_transit.zip.
# Creating GTFS feed for tram
# Processing routes 0 to 51
# About to save complete timetable to file output/3/google_transit.zip ...
# ...finished writing to file output/3/google_transit.zip.
# Creating GTFS feed for vline
# Processing routes 0 to 53
# About to save complete timetable to file output/1/google_transit.zip ...
# ...finished writing to file output/1/google_transit.zip.
#
# Creating output/VITM_2031_GTFS.zip...
#
# Generating GTFS outputs for 2036 reference case
#
# Creating GTFS feed for bus
# Processing routes 0 to 1351
# 44.0% processed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-139-5aaca0006a64> in <module>
#      41         df_shapes.loc[df_shapes['UNIQUE_ROUTE'].isin(unique_route_ids)].drop('UNIQUE_ROUTE',axis=1).to_csv('input/temp/shapes.txt', index=False)
#      42
# ---> 43         create_gtfs_from_basicinfo.run()
#      44
#      45     print('\nCreating output/VITM_'+year+'_GTFS.zip...\n')
#
# ~/Documents/GitHub/vitm-gtfs/create_gtfs_from_basicinfo.py in run()
#     736
#     737     print(('Creating GTFS feed for ' + options.service))
# --> 738     process_data(
#     739         os.path.expanduser('input/temp/' + options.routedefs),
#     740         os.path.expanduser('input/temp/' + options.inputsegments),
#
# ~/Documents/GitHub/vitm-gtfs/create_gtfs_from_basicinfo.py in process_data(route_defs_csv_fname, input_segments_fname, input_stops_fname, mode_config, output, seg_speed_model, memory_db, delete_partials, route_write_batch_size, year, per_route_hways_fname)
#     560         stop_id_to_gtfs_stop_id_map = create_gtfs_stop_entries(stops_shp,
#     561             mode_config, schedule)
# --> 562         create_gtfs_trips_stoptimes(route_defs[r_start:r_end+1],
#     563             route_segments_shp, stops_shp, mode_config, schedule,
#     564             seg_speed_model, route_id_to_gtfs_route_id_map,
#
# ~/Documents/GitHub/vitm-gtfs/create_gtfs_from_basicinfo.py in create_gtfs_trips_stoptimes(route_defs, route_segments_shp, stops_shp, mode_config, schedule, seg_speed_model, route_id_to_gtfs_id_map, stop_id_to_gtfs_stop_id_map, initial_trip_id, per_route_hways, hways_tps)
#     284             gtfs_origin_r_id = route_def.gtfs_origin_id
#     285             avg_hways_for_route = per_route_hways[gtfs_origin_r_id]
# --> 286         ntrips_this_route = create_gtfs_trips_stoptimes_for_route(
#     287             route_def, route_segments_shp,
#     288             stops_shp, mode_config, schedule, seg_speed_model,
#
# ~/Documents/GitHub/vitm-gtfs/create_gtfs_from_basicinfo.py in create_gtfs_trips_stoptimes_for_route(route_def, route_segments_shp, stops_shp, mode_config, schedule, seg_speed_model, gtfs_route_id, stop_id_to_gtfs_stop_id_map, init_trip_ctr, avg_hways_for_route, hways_tps)
#     370         # This way we do this just once per route, direction,
#     371         # and serv period.
# --> 372         prebuilt_stop_info_list = build_stop_list_and_seg_info_along_route(
#     373             route_def, serv_period, 0, route_segments_shp, stops_shp,
#     374             mode_config, schedule, seg_speed_model,
#
# ~/Documents/GitHub/vitm-gtfs/create_gtfs_from_basicinfo.py in build_stop_list_and_seg_info_along_route(route_def, serv_period, dir_id, route_segments_shp, stops_shp, mode_config, schedule, seg_speed_model, stop_id_to_gtfs_stop_id_map)
#     100         (tp_model.SEG_ROUTE_LIST_FIELD, route_def.id)
#     101     route_segments_lyr.SetAttributeFilter(where_clause)
# --> 102     segs_lookup_table = tp_model.build_segs_lookup_table(route_segments_lyr)
#     103     ordered_seg_refs = route_segs.create_ordered_seg_refs_from_ids(
#     104         route_def.ordered_seg_ids, segs_lookup_table)
#
# ~/Documents/GitHub/vitm-gtfs/topology_shapefile_data_model.py in build_segs_lookup_table(route_segments_lyr)
#     156     relevant shapefile or modify the layer, it becomes redundant."""
#     157     lookup_dict = {}
# --> 158     for feature in route_segments_lyr:
#     159         seg_id = (feature.GetField(SEG_ID_FIELD))
#     160         lookup_dict[int(seg_id)] = feature
#
# ~/opt/miniconda3/envs/py3/lib/python3.8/site-packages/osgeo/ogr.py in __iter__(self)
#    2778         self.ResetReading()
#    2779         while True:
# -> 2780             feature = self.GetNextFeature()
#    2781             if not feature:
#    2782                 break
#
# ~/opt/miniconda3/envs/py3/lib/python3.8/site-packages/osgeo/ogr.py in GetNextFeature(self, *args)
#    1344         a handle to a feature, or NULL if no more features are available.
#    1345         """
# -> 1346         return _ogr.Layer_GetNextFeature(self, *args)
#    1347
#    1348
#
# KeyboardInterrupt:
